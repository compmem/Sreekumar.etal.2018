# %%
# %pylab inline
# getting most of my imports and the code for doing the correlations from
# /cmlab/data/fmri/expSamp/anal/ExpSamp_SL_qwarp_log_trim.py
from ExpSamp_SL_qwarp_trans_func import *
from scipy import stats
from joblib import Parallel,delayed
import numpy.lib.recfunctions as nprf
# Out:
# /data/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib
# /data/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
debug.active += ["SLC"]

# <codecell>
class CustomCorrMeasure(Measure):
    def __init__(self, ind_data, index, use_rank=True, formula = None, method = 'pearson',
                 ind_rank_method = rankdata,
                 s_log = False,t_log = False,e_log = False,
                 s_bounds = None, t_bounds = None,
                 verbose = False,return_term_array = 0,zdist = False,ndmetric = 'correlation'):
        """ for right now, it's up to you to make sure that the index matches your ind_data, 
        for a glm that means you need a separate index for each subject, for an LMER it'll be 
        1 big block of independent data and 1 big index. 
        
        ind_rank_method lets you define a function for ranking the independent data
        this lets us deal with ranking and sorting and interaction terms and all of that"""
        Measure.__init__(self)
        self._ind_data = ind_data[index]
        self._index = index
        self._use_rank = use_rank
        self._formula = formula
        self._method = method
        self._ndmetric = ndmetric
        self._subj = np.unique(self._ind_data['subject'])
        self._is1=True
        self._s_log = s_log
        self._t_log = t_log
        self._e_log = e_log
        self.verbose = verbose
        self._return_term_array = return_term_array
        self._zdist = zdist


        if s_bounds != None:
            self._s_bounds = s_bounds
        if t_bounds != None:
            self._t_bounds = t_bounds
        
        if self._s_log == True:
            self._ind_data['space'] = np.log10(self._ind_data['space'])
            self._ind_data['space'][self._ind_data['space']==np.NINF] =0 

        if self._t_log == True:
            self._ind_data['time'] = np.log10(self._ind_data['time'])
            self._ind_data['time'][self._ind_data['time']==np.NINF] =0 
 
        if self._e_log == True:
            self._ind_data['event'] = np.log10(self._ind_data['event'])
            self._ind_data['event'][self._ind_data['event']==np.NINF] =0
            
        if self._use_rank == True:
            # rank the ind data
            self._ind_data = ind_rank_method(self._ind_data)
        else:
            idat_df = pd.DataFrame(self._ind_data)
            idat_df['val'] = np.zeros(idat_df.shape[0])
            self._ind_data = idat_df.to_records()
        
        #figure out how long the results array will be by calling the glm on some dummy data
        if self._method=='glm':
            self._ind_data['val'] = np.random.randn(self._ind_data.shape[0])     
            self._res_len = (smf.glm(formula=self._formula, data=self._ind_data).fit().params.shape[0]*2)+4
            #set val back to zeros just in case
            self._ind_data['val'] = np.zeros(self._ind_data.shape[0])     
    

    def __call__(self, dataset):
    
        if ((self._method == 'pearson') or (self._method == 'glm')):
            if dataset.shape[1] == 1:
                metric = 'euclidean'
            else:
                metric = self._ndmetric
            # calc dist for neural data
            #mask = dataset.samples[-1].astype(np.bool)
            ndist = pdist(dataset.samples, metric=metric)[self._index]
            if self._zdist == True:
                ndist = (ndist-np.average(ndist))/np.std(ndist)
            if self._use_rank:
                #rank it
                ndist = rankdata(ndist)
            
        if self._method == 'pearson':
            # compare it
            r,p = pearsonr(ndist, self._ind_data[self._formula])
    
            # convert to z
            return np.arctan(r)
        
        elif self._method == 'glm':
            betas = {}
            
            #norm the neural ranks
            #print ndist.shape
            #print type(ndist)
            #print self._subj
            if self._use_rank == True:
                 ndist = ndist.astype(np.float)/np.max(ndist)
            
            #set val in ind_data equal to dep_data for that feature
            self._ind_data['val']=ndist
            #fit glm based on model given in fe_formula
            try:
                modl= smf.glm(formula=self._formula, data=self._ind_data)
                modl.raise_on_perfect_prediction = False
            except (LinAlgError, ValueError):
                return np.zeros(self._res_len)
            try:
                modl = modl.fit()
            except PerfectSeparationError:
                #print "Perfect Separation Error, returning 0 in blind optimism"
                return np.zeros(self._res_len)
                #save beta's for each factor to an array 

            #for fac in modl.pvalues.keys():              
            #    betas[fac]=modl.params[fac]
            betas = np.array([modl.params[fac] for fac in sorted(modl.pvalues.keys())])
            betas = np.append(betas,np.array([modl.tvalues[fac] for fac in sorted(modl.pvalues.keys())]))            
            betas = np.append(betas,modl.deviance)
            betas = np.append(betas,modl.scale)
            betas = np.append(betas,modl.llf)
            betas = np.append(betas, dataset.nfeatures) #this was np.append(betas,mask.sum()) 
            if self.verbose == True:

                if self._is1 == True:
                    k=0            
                    for fac in sorted(modl.pvalues.keys()):
                        print k,fac,"betas"
                        k+=1
                    for fac in sorted(modl.pvalues.keys()):
                        print k,fac,"tvals"
                        k+=1
                    print k,"deviance"
                    print k+1,"scale"
                    print k+2,"llf"
                    print k+3,"count"
                    self._is1=False
            if self._return_term_array == 2:

                terms = []           
                for fac in sorted(modl.pvalues.keys()):
                    terms.append(fac+'_betas')
                for fac in sorted(modl.pvalues.keys()):
                    terms.append(fac+"_tvals")
                terms.append("deviance")
                terms.append("scale")
                terms.append("llf")
                terms.append("count")
                return terms
            elif self._return_term_array == 1:
                return sorted(modl.pvalues.keys())
                
            return betas
        

            
        
        elif self._method == 'lmer':
            raise error('%s method not implemented'%self._method)
        else:
            raise error('%s method not implemented'%self._method)

# %%
def rank_norm_data(idat,subf='subject',psf='pair_str',tf='time',sf='space',cf='correl',sxtf='spaceXtime'):
    """"rank data man"""
    #rank new independent data in place
    idat_df = pd.DataFrame(idat)
    #print np.unique(idat[psf])
    #print idat_df.columns
    subj = np.unique(idat[subf])
    #print subj
    idat_df['val'] =np.zeros((idat_df.shape[0],1))
    
    
    tl = []
    sl = []
    sxtl = []
    cl = []
    for s in np.unique(idat[subf]):
        tr = rankdata(idat_df.ix[idat_df[subf]==s][tf])
        sr = rankdata(idat_df.ix[idat_df[subf]==s][sf])
        cr = rankdata(idat_df.ix[idat_df[subf]==s][cf])
        sxtr = rankdata(sr*tr)
    
        #norm ranks to be between 0 an 1
        tl = np.append(tl,tr/np.float(np.max(tr)))
        sl = np.append(sl,sr/np.float(np.max(sr)))
        cl = np.append(cl,cr/np.float(np.max(cr)))
        sxtl = np.append(sxtl,sxtr/np.float(np.max(sxtr)))
            
    idat_df[tf]=tl
    idat_df[sf]=sl
    idat_df[cf]=cl
    idat_df[sxtf]=sxtl
            
    return idat_df.to_records()


def addval(idat):
    #rank new independent data in place
    idat_df = pd.DataFrame(idat)
    idat_df['val'] =np.zeros((idat_df.shape[0],1))
    return idat_df.to_records()

# %%
# function needed for graphing to change the axes

def adjust_spines(ax, spines,smart_bounds=True):
    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 10))  # outward by 10 points
            spine.set_smart_bounds(smart_bounds)
        else:
            spine.set_color('none')  # don't draw spine

    # turn off ticks where there is no spine
    if 'left' in spines:
        ax.yaxis.set_ticks_position('left')
    else:
        # no yaxis ticks
        ax.yaxis.set_ticks([])

    if 'bottom' in spines:
        ax.xaxis.set_ticks_position('bottom')
    else:
        # no xaxis ticks
        ax.xaxis.set_ticks([])
# Change the default mathtest font to regular instead of italics
# so that the log10s on the graph are regular font
mpl.rcParams['mathtext.default'] = 'regular'

# Change the default font for figures so that they all look the same
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 10}

matplotlib.rc('font', **font)

# %%
def log10_nan(x):
    nx = np.log10(x)
    nx[nx==np.NINF] =0
    return nx
def log10_nan_500k(x):
    nx = np.log10(x)
    nx[nx==np.NINF] =0
    return nx + 500000
def log10_nan01(x,xmax,xmin):
    nx = np.log10(x)
    nx[nx==np.NINF] =0
    nxmax = np.log10(xmax)
    nxmin = np.log10(xmin)
    nx = (nx-nxmin)/(nxmax-nxmin)
    return nx
def linear01(x,xmax,xmin):
    nx = (x-xmin)/(xmax-xmin)
    return nx
def exponential01(x,xmax,xmin):
    nx = np.exp((x/xmax))
    nxmax = np.exp(1)
    nxmin = np.exp((xmin/xmax))
    nx = (nx-nxmin)/(nxmax-nxmin)
    return nx

# %%
#define formula for glm, this is also a thing that may change run to run
#fe_formula = 'val~ham+ham:viv_ave+viv_ave+correl+event'  # MODEL 1
#run_name = 'perm_hamvivcorrel_stlim_roi_zndist_1000perms_v1' #this one you should probably change for each run

#fe_formula = 'val~ham+correl+event' # MODEL 4
#run_name = 'perm_hamcorrel_stlim_roi_zndist_1000perms_v1'

# this dictionary sets the parameters for the run(s)
lim_dict = dict(hvce=dict(run_name='perm_hamvivcorrel_stlim_roi_zndist_1000perms_v1',
                           fe_formula='val~ham+ham:viv_ave+viv_ave+correl+event',
                           str_only = False,
                           spacemax = 10.**4.5,
                           spacemin = 10**2.0,
                           timemin = 10**4.75,
                           timemax =  10007180.,
                           roi_dir = "standard",
                           ndmetric = "correlation",
                           s_log = False,
                           t_log = False,
                           e_log = True),
                hce=dict(run_name='perm_hamcorrel_stlim_roi_zndist_1000perms_v1',
                           fe_formula='val~ham+correl+event',
                           str_only = False,
                           spacemax = 10.**4.5,
                           spacemin = 10**2.0,
                           timemin = 10**4.75,
                           timemax =  10007180.,
                           roi_dir = "standard",
                           ndmetric = "correlation",
                           s_log = False,
                           t_log = False,
                           e_log = True),
                hvcest=dict(run_name='perm_hamvivcorrelspacetime_stlim_roi_zndist_1000perms_v1',
                           fe_formula='val~ham+ham:viv_ave+space*time+viv_ave+correl+event',
                           str_only = False,
                           spacemax = 10.**4.5,
                           spacemin = 10**2.0,
                           timemin = 10**4.75,
                           timemax =  10007180.,
                           roi_dir = "standard",
                           ndmetric = "correlation",
                           s_log = True,
                           t_log = True,
                           e_log = True),
                hcest=dict(run_name='perm_hamcorrel_stlim_roi_zndist_1000perms_v1',
                           fe_formula='val~ham+correl+space*time+event',
                           str_only = False,
                           spacemax = 10.**4.5,
                           spacemin = 10**2.0,
                           timemin = 10**4.75,
                           timemax =  10007180.,
                           roi_dir = "standard",
                           ndmetric = "correlation",
                           s_log = True,
                           t_log = True,
                           e_log = True)
               )

# %%
run_name="temp"

# %%
#set all the pathy paths
method = 'glm'
run_type = '%s_sl'%(method)

basedir = '/data/nielsond/expSamp/data/'
data_dir = os.path.join(basedir,'input')
#data_file = 'rsa_dataset_gps_time_old_exclude_viv_bin_scan_time_rem_ham.pickle'  
data_file = 'rsa_dataset_gps_time_old_exclude_drop_viv_bin_scan_time_rem_ham.pickle'  

outdir = '/data/nielsond/expSamp/data/output/%s_sl/%s'%(method,run_name)
ss_out_pat = 'betas.%s.%s.%s.%03d.nii.gz'
combined_out_pat = '%s.%s.%s.nii.gz'
fmri_pat = 'stb.%s_stb_qwarp_e2a.nii.gz'
subj_mask_pat = '%s_mask_GM_full_+tlrc.nii.gz'
errts_pat= 'errts.anaticor.%s_stb_qwarp_e2a+tlrc.nii.gz'
mask_pat='/data/nielsond/expSamp/data/input/MNI152_T1_2.5mm_GM_mask.nii.gz'
stdroidir = os.path.join(data_dir,'all_rois')

subjects = ['expSamp01',
            'expSamp02',
            'expSamp03',
            'expSamp04',
            'expSamp05',
            'expSamp07',
            'expSamp08',
            'expSamp09',
            'expSamp10']

roi_paths = ['LeftAntHippocampus.nii.gz',
             'LeftMidHippocampus.nii.gz',
             'LeftPostHippocampus.nii.gz',
             'Left_Parahippocampal_G.nii.gz',
             'RightAntHippocampus.nii.gz',
             'RightMidHippocampus.nii.gz',
             'RightPostHippocampus.nii.gz',
             'Right_Parahippocampal_G.nii.gz',
             'Left_Posterior_V1.nii.gz',
             'Right_Posterior_V1.nii.gz']
#roi_paths = ['LeftAntHippocampus.nii.gz']

# %%
# load independent data
dat = np.load(os.path.join(data_dir,data_file))

# swap strong and weak so that the main effects relflect pair strength strong
# not relevant anymore, don't want to take it out, might break something
# dat['pair_str'] = ['3weak' if dat['pair_str'][i] == '1weak' else '1strong' if dat['pair_str'][i]=='3strong' else dat['pair_str'][i] for i in range(len(dat))]

# %%
data_file_old = 'rsa_dataset_gps_time_correl_all.pickle'
dat_old = np.load(os.path.join(data_dir,data_file_old))

# %%
cd_new = []
for i in range(len(dat)):
    ind = ((dat_old['subject'] == dat['subject'][i]) & ( dat_old['s1_trial'] == dat['s1_trial'][i]) & (dat_old['s2_trial'] == dat['s2_trial'][i]))
    cd_new.append(dat_old['correl'][ind])

# %%
dat = nprf.rec_append_fields(dat,'correl',np.array(cd_new).squeeze())

# %%
# Drop 118 from expSamp07 (bad single trial beta)
sind = (dat['subject']=='expSamp07') & ((dat['s1_trial']==118) | (dat['s2_trial']==118))
for i in range(len(sind)):
    if sind[i]== True:
        dat[i]['pair_str']='0exclude'
        
dat = dat[dat['pair_str']!='0exclude']

# %%
# do some subject level preprocessing so that we can reduce the overhead for each perm
limits = lim_dict.keys()[0]
kept_stims = {}
for subj in subjects:
    ind = ((dat['subject']==subj) & (dat['pair_str'] != '0exclude'))
    s1_exclude = np.array(np.unique(dat[ind]['s1_trial']))
    s2_exclude = np.array(np.unique(dat[ind]['s2_trial']))
    kept_stims[subj] = np.unique(np.hstack([s1_exclude,s2_exclude]))-1

# %%
# create roi dictionary
rois = {}
for roi in roi_paths:
    rois[roi]={}
    for subj in subjects:
        rois[roi][subj]= nb.load(os.path.join(stdroidir,'MNI152_2.5mm_'+roi)).get_data()

# %%
# load all the dependent data so that we can iterate over subjects and not have to reload the data each time
# this takes a while depending on how many different runs you are doing, but will save time on each perm
# yes there are probably more memory effecient ways to do this
# please implement one if memory is an issue for you
mask_dict = {subj: nb.load
             (os.path.join(data_dir,subj_mask_pat%(subj))).get_data() for subj in subjects}
roi_mask_dict = {roi:{subj:((mask_dict[subj]>0)&(rois[roi][subj]>0)) for subj in subjects}for roi in roi_paths}
ds_dict = {roi:{subj:fmri_dataset(os.path.join(data_dir,fmri_pat%(subj)),mask=roi_mask_dict[roi][subj]) for subj in subjects}for roi in roi_paths}
# Out:
# WARNING: Detected incorrect (nan) scl_ fields. Resetting to scl_slope=1.0 and scl_inter=0.0
#  * Please note: warnings are printed only once, but underlying problem might occur many times *

# %%
with open('/data/nielsond/expSamp/data/input/ham_perms_all.npz','rb') as handle:
    perm_dict = pickle.load(handle)

# %%
# if you want to save youself some time, or anticipate the possiblity of a crash,
# write out the ds dict, I'm writing it out to my home directory so it doesn't clog up teh server
with open(os.path.join(data_dir,'ham_roi_ds_dict.npz'),'wb') as handle:
    pickle.dump(ds_dict,handle)

# %%
# if you saved out the ds data in the above cell, and need to recover from a crash,
# Huzzah! you can just load in the dependent data HERE
with open(os.path.join(data_dir,'ham_roi_ds_dict.npz'),'rb') as handle:
    ds_dict = pickle.load(handle)

# %%
nperms = 1001

# %%
#this will run the perms for all the runs in serial, slow, but doesn't crash
lim_res = {limit:{roi:{subj:[] for subj in subjects}for roi in roi_paths} for limit in lim_dict.keys()}
# Since we're not dropping mixed valence pairs, we can permute before calculating the distance matrix
for limits in lim_dict.keys():
    #for subj in subjects:
    #    #for roi_path in roi_paths:
    print(limits)
    subj = subjects[0]
    roi_path = roi_paths[0]
    ds = ds_dict[roi_path][subj][perm_dict[subj][i]]

    if lim_dict[limits]['str_only'] == True:
        ind = ((dat[dat['subject']==subj]['pair_str']=='1strong') &
                (dat[dat['subject']==subj]['space'] < lim_dict[limits]['spacemax']) & (dat[dat['subject'] == subj]['space'] > lim_dict[limits]['spacemin']) &
                (dat[dat['subject']==subj]['time'] > lim_dict[limits]['timemin']) & (dat[dat['subject']==subj]['time'] < lim_dict[limits]['timemax']))
    else:
        ind = ( 
                (dat[dat['subject']==subj]['space'] < lim_dict[limits]['spacemax']) & (dat[dat['subject'] == subj]['space'] > lim_dict[limits]['spacemin']) &
                (dat[dat['subject']==subj]['time'] > lim_dict[limits]['timemin']) & (dat[dat['subject']==subj]['time'] < lim_dict[limits]['timemax']))

    dsmetric = CustomCorrMeasure(dat[dat['subject']==subj],ind, 
                                 use_rank=False, formula = lim_dict[limits]['fe_formula'], 
                                 method = method,
                                 s_log= True, t_log = True, e_log = True,
                                 zdist = True, ndmetric = lim_dict[limits]['ndmetric'], verbose=True)

    lim_res[limits][roi_path][subj].append(dsmetric.__call__(ds))
print i,
# Out:
# hvcest
# 0 Intercept betas
# 1 correl betas
# 2 event betas
# 3 ham betas
# 4 ham:viv_ave betas
# 5 space betas
# 6 space:time betas
# 7 time betas
# 8 viv_ave betas
# 9 Intercept tvals
# 10 correl tvals
# 11 event tvals
# 12 ham tvals
# 13 ham:viv_ave tvals
# 14 space tvals
# 15 space:time tvals
# 16 time tvals
# 17 viv_ave tvals
# 18 deviance
# 19 scale
# 20 llf
# 21 count
# hvce
# 0 Intercept betas
# 1 correl betas
# 2 event betas
# 3 ham betas
# 4 ham:viv_ave betas
# 5 viv_ave betas
# 6 Intercept tvals
# 7 correl tvals
# 8 event tvals
# 9 ham tvals
# 10 ham:viv_ave tvals
# 11 viv_ave tvals
# 12 deviance
# 13 scale
# 14 llf
# 15 count
# hcest
# 0 Intercept betas
# 1 correl betas
# 2 event betas
# 3 ham betas
# 4 space betas
# 5 space:time betas
# 6 time betas
# 7 Intercept tvals
# 8 correl tvals
# 9 event tvals
# 10 ham tvals
# 11 space tvals
# 12 space:time tvals
# 13 time tvals
# 14 deviance
# 15 scale
# 16 llf
# 17 count
# hce
# 0 Intercept betas
# 1 correl betas
# 2 event betas
# 3 ham betas
# 4 Intercept tvals
# 5 correl tvals
# 6 event tvals
# 7 ham tvals
# 8 deviance
# 9 scale
# 10 llf
# 11 count
# 19

# %%
lim_res
# Out:
# {'hce': {'LeftAntHippocampus.nii.gz': {'expSamp01': [array([ -1.51608539e+00,   4.17551857e-01,   3.18998865e-01,
#              1.59929591e-03,  -4.29135793e+00,   1.74427246e+00,
#              6.78034981e+00,   2.03650048e-01,   2.16669301e+03,
#              9.77308529e-01,  -3.12397150e+03,   1.43000000e+02]),
#     array([  1.72326093e-01,  -1.44216223e-01,   4.63443812e-02,
#             -1.41660460e-02,   4.82187504e-01,  -5.95541259e-01,
#              9.73764375e-01,  -1.78319226e+00,   2.21722475e+03,
#              1.00010138e+00,  -3.14957325e+03,   1.43000000e+02]),
#     array([  7.71966854e-01,  -5.43431793e-01,   2.66794897e-02,
#             -1.10485225e-02,   2.16160098e+00,  -2.24571555e+00,
#              5.60978579e-01,  -1.39176430e+00,   2.21404165e+03,
#              9.98665608e-01,  -3.14797785e+03,   1.43000000e+02])],
#    'expSamp02': [array([ -1.49938549e+00,   4.43055933e-01,   2.68293908e-01,
#              1.52202484e-02,  -3.87004791e+00,   1.69093971e+00,
#              4.37524205e+00,   1.51425786e+00,   1.40325555e+03,
#              9.78560357e-01,  -2.02284807e+03,   1.08000000e+02]),
#     array([ -1.34655236e-01,   2.43409081e-01,  -1.26578354e-01,
#              2.08892052e-02,  -3.44237018e-01,   9.20105505e-01,
#             -2.04447594e+00,   2.05840723e+00,   1.43045498e+03,
#             -1.00127349e+00,   1.81709493e+00,  -6.13066076e-02,
#             -2.52879450e-01,  -2.73836877e-01,   1.32780565e+00,
#              2.82554572e+03,   9.63035351e-01,  -4.11600493e+03,
#              8.80000000e+01])]}}}

# %%
#funciton to do the perms in parallel
def run_perm(i,lim_dict,roi_paths,subjects,dat,ds_dict,perm_dict,CustomCorrMeasure):
    lim_res_perm = {limit:{roi:{subj:[] for subj in subjects}for roi in roi_paths} for limit in lim_dict.keys()}

    for limits in lim_dict.keys():
        for subj in subjects:
            for roi_path in roi_paths:
                
                ds = ds_dict[roi_path][subj][perm_dict[subj][i]]
                
                if lim_dict[limits]['str_only'] == True:
                    ind = ((dat[dat['subject']==subj]['pair_str']=='1strong') &
                            (dat[dat['subject']==subj]['space'] < lim_dict[limits]['spacemax']) & (dat[dat['subject'] == subj]['space'] > lim_dict[limits]['spacemin']) &
                            (dat[dat['subject']==subj]['time'] > lim_dict[limits]['timemin']) & (dat[dat['subject']==subj]['time'] < lim_dict[limits]['timemax']))
                else:
                    ind = ( 
                            (dat[dat['subject']==subj]['space'] < lim_dict[limits]['spacemax']) & (dat[dat['subject'] == subj]['space'] > lim_dict[limits]['spacemin']) &
                            (dat[dat['subject']==subj]['time'] > lim_dict[limits]['timemin']) & (dat[dat['subject']==subj]['time'] < lim_dict[limits]['timemax']))
                    
                dsmetric = CustomCorrMeasure(dat[dat['subject']==subj],ind, 
                                             use_rank=False, formula = lim_dict[limits]['fe_formula'], 
                                             method = method,
                                             s_log= True, t_log = True, e_log = True,
                                             zdist = True, ndmetric = lim_dict[limits]['ndmetric'])
                lim_res_perm[limits][roi_path][subj].append(dsmetric.__call__(ds))
    return lim_res_perm

# %%
perm_res = Parallel(n_jobs = 2, verbose = 10)(delayed(run_perm)(i,lim_dict,roi_paths,subjects,dat,ds_dict,perm_dict,CustomCorrMeasure) for i in range(nperms))
# Out:
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=2)]: Done  57 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=2)]: Done  68 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=2)]: Done  81 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=2)]: Done 109 tasks      | elapsed: 28.5min
# [Parallel(n_jobs=2)]: Done 124 tasks      | elapsed: 32.2min
# [Parallel(n_jobs=2)]: Done 141 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=2)]: Done 158 tasks      | elapsed: 40.6min
# [Parallel(n_jobs=2)]: Done 177 tasks      | elapsed: 45.0min
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed: 49.5min
# [Parallel(n_jobs=2)]: Done 217 tasks      | elapsed: 54.7min
# [Parallel(n_jobs=2)]: Done 238 tasks      | elapsed: 59.7min
# [Parallel(n_jobs=2)]: Done 261 tasks      | elapsed: 65.3min
# [Parallel(n_jobs=2)]: Done 284 tasks      | elapsed: 70.7min
# [Parallel(n_jobs=2)]: Done 309 tasks      | elapsed: 76.9min
# [Parallel(n_jobs=2)]: Done 334 tasks      | elapsed: 82.8min
# [Parallel(n_jobs=2)]: Done 361 tasks      | elapsed: 90.7min
# [Parallel(n_jobs=2)]: Done 388 tasks      | elapsed: 98.5min

# %%
! mkdir /data/nielsond/expSamp/data/output/glm_roi/vishu_res

# %%
#convert the data structure from the parallel version to nested dicts

lim_res = {limit:{roi:{subj:[] for subj in subjects}for roi in roi_paths} for limit in lim_dict.keys()}
for i in range(nperms):
    for limits in lim_dict.keys():
        for subj in subjects:
            for roi_path in roi_paths:
                lim_res[limits][roi_path][subj].append(perm_res[i][limits][roi_path][subj])
                
               
for i in range(nperms):
    for limits in lim_dict.keys():
        for subj in subjects:
            for roi_path in roi_paths:
                lim_res[limits][roi_path][subj] = np.array(lim_res[limits][roi_path][subj]).squeeze()

# %%
# !mkdir /data/nielsond/expSamp/data/output/glm_sl/tse_log_log500k

# %%
#save results
with open('/data/nielsond/expSamp/data/output/glm_roi/vishu_res/ham_roi_res_1000.npx','wb') as handle:
    pickle.dump(lim_res,handle)

# %%
#load results
with open('/home/dylan/data/fmri/expSamp/data/tse_v1_10k_res_rem.npz','rb') as handle:
    lim_res = pickle.load(handle)

# %%
lim_res.keys()
term_dict = dict()
term_dict['hce'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas",
                    "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals",
                    "deviance", "scale", "llf", "count"]
term_dict['hcest'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas", "space_betas", "space:time_betas", "time_betas",
                      "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals", "space_tvals", "space:time_tvals", "time_tvals",
                      "deviance", "scale", "llf", "count"]
term_dict['hvce'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas", "ham:viv_ave_betas", "viv_ave_betas",
                     "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals", "ham:viv_ave_tvals", "viv_ave_tvals",
                     "deviance", "scale", "llf", "count"]
term_dict['hvcest'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas", "ham:viv_ave_betas", "space_betas", "space:time_betas", "time_betas", "viv_ave_betas",
                       "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals", "ham:viv_ave_tvals", "space_tvals", "space:time_tvals", "time_tvals", "viv_ave_tvals",
                       "deviance", "scale", "llf", "count"]
lim_dict['hce']['terms'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas",
                    "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals",
                    "deviance", "scale", "llf", "count"]
lim_dict['hcest']['terms'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas", "space_betas", "space:time_betas", "time_betas",
                      "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals", "space_tvals", "space:time_tvals", "time_tvals",
                      "deviance", "scale", "llf", "count"]
lim_dict['hvce']['terms'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas", "ham:viv_ave_betas", "viv_ave_betas",
                     "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals", "ham:viv_ave_tvals", "viv_ave_tvals",
                     "deviance", "scale", "llf", "count"]
lim_dict['hvcest']['terms'] = ["Intercept_betas", "correl_betas", "event_betas", "ham_betas", "ham:viv_ave_betas", "space_betas", "space:time_betas", "time_betas", "viv_ave_betas",
                       "Intercept_tvals", "correl_tvals", "event_tvals", "ham_tvals", "ham:viv_ave_tvals", "space_tvals", "space:time_tvals", "time_tvals", "viv_ave_tvals",
                       "deviance", "scale", "llf", "count"]
print ([(k,len(term_dict[k])) for k in term_dict.keys()])
# Out:
# [('hvcest', 22), ('hvce', 16), ('hcest', 18), ('hce', 12)]

# %%
# I clearly used to be insane, convert this horible nested dataset into a tidy dataframe
resl = []
for limits in lim_res.keys():
    for subj in subjects:
        for roi_path in lim_res[limits].keys():
            for n in range(len(lim_res[limits][roi_path][subj])):
                for i,t in enumerate(term_dict[limits]):
                    r = {}
                    r['n'] = n
                    r['subject'] = subj
                    r['roi_path'] = roi_path
                    r['model'] = limits
                    r['term'] = t
                    r['value'] = lim_res[limits][roi_path][subj][n][i]
                    resl.append(r)
                
resdf = pd.DataFrame(resl)

# %%
resdf.to_csv('/data/nielsond/expSamp/data/output/glm_roi/vishu_res/ham_roi_res_1000.csv')

# %%
resdf = pd.read_csv('/data/nielsond/expSamp/data/output/glm_roi/vishu_res/ham_roi_res_1000.csv', index_col=0)
# Out:
# /data/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/numpy/lib/arraysetops.py:379: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
resdf.head()
# Out:
#     model  n                  roi_path    subject               term     value
# 0  hvcest  0  Left_Posterior_V1.nii.gz  expSamp01    Intercept_betas -1.512135
# 1  hvcest  0  Left_Posterior_V1.nii.gz  expSamp01       correl_betas  0.335867
# 2  hvcest  0  Left_Posterior_V1.nii.gz  expSamp01        event_betas  0.114491
# 3  hvcest  0  Left_Posterior_V1.nii.gz  expSamp01          ham_betas -0.000868
# 4  hvcest  0  Left_Posterior_V1.nii.gz  expSamp01  ham:viv_ave_betas  0.051770

# %%
limits =  lim_dict.keys()[0]

# %%
toidf = resdf.loc[resdf.term.str.contains('betas') & ~resdf.term.str.contains('Intercept') & ~resdf.term.str.contains('event') & ~resdf.term.str.contains('correl'),:]

# %%
toi_ts = toidf.groupby(['model', 'n','roi_path', 'term']).value.apply(lambda x:stats.ttest_1samp(x, 0)[0])

# %%
toi_ts = pd.DataFrame(toi_ts).reset_index()

# %%
toi_conj = toi_ts.query('term=="ham_betas"').merge(toi_ts.query('term=="ham:viv_ave_betas"'),
                                        how='right',
                                        on=['model','n','roi_path'],
                                        suffixes=['_ham','_ham:viv_ave'])

# %%
toi_conj['value_ham:viv_ave'] *=  -1

# %%
toi_conj['value'] = toi_conj.loc[:,['value_ham', 'value_ham:viv_ave']].min(1)

# %%
null_dist = sorted(toi_conj.groupby(['n']).value.max().values)
true_res =  toi_conj.query('n == 0')
true_res['all_term_all_roi_p'] = (len(null_dist) - np.searchsorted(null_dist,true_res.value))/(len(null_dist) * 1.0)
# Out:
# /spin1/users/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
true_res
# Out:
#         model  n                        roi_path   term_ham  value_ham  \
# 0        hvce  0       LeftAntHippocampus.nii.gz  ham_betas   1.120707
# 1        hvce  0       LeftMidHippocampus.nii.gz  ham_betas   3.659472
# 2        hvce  0      LeftPostHippocampus.nii.gz  ham_betas   0.876254
# 3        hvce  0   Left_Parahippocampal_G.nii.gz  ham_betas   1.227161
# 4        hvce  0        Left_Posterior_V1.nii.gz  ham_betas   0.305826
# 5        hvce  0      RightAntHippocampus.nii.gz  ham_betas   1.462987
# 6        hvce  0      RightMidHippocampus.nii.gz  ham_betas   2.166649
# 7        hvce  0     RightPostHippocampus.nii.gz  ham_betas   1.977120
# 8        hvce  0  Right_Parahippocampal_G.nii.gz  ham_betas   1.976442
# 9        hvce  0       Right_Posterior_V1.nii.gz  ham_betas   2.646504
# 10010  hvcest  0       LeftAntHippocampus.nii.gz  ham_betas   1.004986
# 10011  hvcest  0       LeftMidHippocampus.nii.gz  ham_betas   3.810661
# 10012  hvcest  0      LeftPostHippocampus.nii.gz  ham_betas   1.047838
# 10013  hvcest  0   Left_Parahippocampal_G.nii.gz  ham_betas   1.326364
# 10014  hvcest  0        Left_Posterior_V1.nii.gz  ham_betas   0.396511
# 10015  hvcest  0      RightAntHippocampus.nii.gz  ham_betas   1.469204
# 10016  hvcest  0      RightMidHippocampus.nii.gz  ham_betas   1.988997
# 10017  hvcest  0     RightPostHippocampus.nii.gz  ham_betas   2.195709
# 10018  hvcest  0  Right_Parahippocampal_G.nii.gz  ham_betas   2.057347
# 10019  hvcest  0       Right_Posterior_V1.nii.gz  ham_betas   2.641590
#
#         term_ham:viv_ave  value_ham:viv_ave     value  all_term_all_roi_p
# 0      ham:viv_ave_betas          -0.458617 -0.458617            0.998002
# 1      ham:viv_ave_betas           0.803610  0.803610            0.695305
# 2      ham:viv_ave_betas           0.632704  0.632704            0.776224
# 3      ham:viv_ave_betas           0.541943  0.541943            0.819181
# 4      ham:viv_ave_betas           0.168196  0.168196            0.938062
# 5      ham:viv_ave_betas          -0.193947 -0.193947            0.984016
# 6      ham:viv_ave_betas           1.318648  1.318648            0.413586
# 7      ham:viv_ave_betas           1.648644  1.648644            0.246753
# 8      ham:viv_ave_betas           1.252307  1.252307            0.453546
# 9      ham:viv_ave_betas           2.860631  2.646504            0.044955
# 10010  ham:viv_ave_betas          -0.477614 -0.477614            0.998002
# 10011  ham:viv_ave_betas           0.804561  0.804561            0.693307
# 10012  ham:viv_ave_betas           0.921162  0.921162            0.629371
# 10013  ham:viv_ave_betas           0.639489  0.639489            0.773227
# 10014  ham:viv_ave_betas           0.240640  0.240640            0.919081
# 10015  ham:viv_ave_betas          -0.241915 -0.241915            0.987013
# 10016  ham:viv_ave_betas           1.278699  1.278699            0.433566
# 10017  ham:viv_ave_betas           1.926423  1.926423            0.154845
# 10018  ham:viv_ave_betas           1.292187  1.292187            0.424575
# 10019  ham:viv_ave_betas           3.029674  2.641590            0.044955

# %%
toi_ts.query('term=="ham:viv_ave_betas"')
# Out:
#          model     n                        roi_path               term  \
# 50050     hvce     0       LeftAntHippocampus.nii.gz  ham:viv_ave_betas
# 50053     hvce     0       LeftMidHippocampus.nii.gz  ham:viv_ave_betas
# 50056     hvce     0      LeftPostHippocampus.nii.gz  ham:viv_ave_betas
# 50059     hvce     0   Left_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 50062     hvce     0        Left_Posterior_V1.nii.gz  ham:viv_ave_betas
# 50065     hvce     0      RightAntHippocampus.nii.gz  ham:viv_ave_betas
# 50068     hvce     0      RightMidHippocampus.nii.gz  ham:viv_ave_betas
# 50071     hvce     0     RightPostHippocampus.nii.gz  ham:viv_ave_betas
# 50074     hvce     0  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 50077     hvce     0       Right_Posterior_V1.nii.gz  ham:viv_ave_betas
# 50080     hvce     1       LeftAntHippocampus.nii.gz  ham:viv_ave_betas
# 50083     hvce     1       LeftMidHippocampus.nii.gz  ham:viv_ave_betas
# 50086     hvce     1      LeftPostHippocampus.nii.gz  ham:viv_ave_betas
# 50089     hvce     1   Left_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 50092     hvce     1        Left_Posterior_V1.nii.gz  ham:viv_ave_betas
# 50095     hvce     1      RightAntHippocampus.nii.gz  ham:viv_ave_betas
# 50098     hvce     1      RightMidHippocampus.nii.gz  ham:viv_ave_betas
# 50101     hvce     1     RightPostHippocampus.nii.gz  ham:viv_ave_betas
# 50104     hvce     1  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 50107     hvce     1       Right_Posterior_V1.nii.gz  ham:viv_ave_betas
# 50110     hvce     2       LeftAntHippocampus.nii.gz  ham:viv_ave_betas
# 50113     hvce     2       LeftMidHippocampus.nii.gz  ham:viv_ave_betas
# 50116     hvce     2      LeftPostHippocampus.nii.gz  ham:viv_ave_betas
# 50119     hvce     2   Left_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 50122     hvce     2        Left_Posterior_V1.nii.gz  ham:viv_ave_betas
# 50125     hvce     2      RightAntHippocampus.nii.gz  ham:viv_ave_betas
# 50128     hvce     2      RightMidHippocampus.nii.gz  ham:viv_ave_betas
# 50131     hvce     2     RightPostHippocampus.nii.gz  ham:viv_ave_betas
# 50134     hvce     2  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 50137     hvce     2       Right_Posterior_V1.nii.gz  ham:viv_ave_betas
# ...        ...   ...                             ...                ...
# 139960  hvcest   998       LeftAntHippocampus.nii.gz  ham:viv_ave_betas
# 139966  hvcest   998       LeftMidHippocampus.nii.gz  ham:viv_ave_betas
# 139972  hvcest   998      LeftPostHippocampus.nii.gz  ham:viv_ave_betas
# 139978  hvcest   998   Left_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 139984  hvcest   998        Left_Posterior_V1.nii.gz  ham:viv_ave_betas
# 139990  hvcest   998      RightAntHippocampus.nii.gz  ham:viv_ave_betas
# 139996  hvcest   998      RightMidHippocampus.nii.gz  ham:viv_ave_betas
# 140002  hvcest   998     RightPostHippocampus.nii.gz  ham:viv_ave_betas
# 140008  hvcest   998  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 140014  hvcest   998       Right_Posterior_V1.nii.gz  ham:viv_ave_betas
# 140020  hvcest   999       LeftAntHippocampus.nii.gz  ham:viv_ave_betas
# 140026  hvcest   999       LeftMidHippocampus.nii.gz  ham:viv_ave_betas
# 140032  hvcest   999      LeftPostHippocampus.nii.gz  ham:viv_ave_betas
# 140038  hvcest   999   Left_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 140044  hvcest   999        Left_Posterior_V1.nii.gz  ham:viv_ave_betas
# 140050  hvcest   999      RightAntHippocampus.nii.gz  ham:viv_ave_betas
# 140056  hvcest   999      RightMidHippocampus.nii.gz  ham:viv_ave_betas
# 140062  hvcest   999     RightPostHippocampus.nii.gz  ham:viv_ave_betas
# 140068  hvcest   999  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 140074  hvcest   999       Right_Posterior_V1.nii.gz  ham:viv_ave_betas
# 140080  hvcest  1000       LeftAntHippocampus.nii.gz  ham:viv_ave_betas
# 140086  hvcest  1000       LeftMidHippocampus.nii.gz  ham:viv_ave_betas
# 140092  hvcest  1000      LeftPostHippocampus.nii.gz  ham:viv_ave_betas
# 140098  hvcest  1000   Left_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 140104  hvcest  1000        Left_Posterior_V1.nii.gz  ham:viv_ave_betas
# 140110  hvcest  1000      RightAntHippocampus.nii.gz  ham:viv_ave_betas
# 140116  hvcest  1000      RightMidHippocampus.nii.gz  ham:viv_ave_betas
# 140122  hvcest  1000     RightPostHippocampus.nii.gz  ham:viv_ave_betas
# 140128  hvcest  1000  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas
# 140134  hvcest  1000       Right_Posterior_V1.nii.gz  ham:viv_ave_betas
#
#            value
# 50050   0.458617
# 50053  -0.803610
# 50056  -0.632704
# 50059  -0.541943
# 50062  -0.168196
# 50065   0.193947
# 50068  -1.318648
# 50071  -1.648644
# 50074  -1.252307
# 50077  -2.860631
# 50080   1.803104
# 50083   0.439201
# 50086  -0.864892
# 50089   0.418218
# 50092   2.129319
# 50095   1.086552
# 50098  -0.717291
# 50101   0.101219
# 50104   0.721738
# 50107   2.114063
# 50110  -0.513963
# 50113   0.294485
# 50116   1.095189
# 50119  -0.712496
# 50122   0.338867
# 50125  -1.162641
# 50128  -0.636970
# 50131   0.330958
# 50134  -0.366122
# 50137   0.424359
# ...          ...
# 139960 -0.302616
# 139966 -1.162682
# 139972 -0.076367
# 139978 -1.296172
# 139984 -2.798561
# 139990  0.304537
# 139996  0.647172
# 140002  0.550457
# 140008 -0.946567
# 140014 -2.283364
# 140020  0.700843
# 140026 -0.349335
# 140032  0.645453
# 140038  1.036765
# 140044 -0.507542
# 140050  0.628881
# 140056 -0.234852
# 140062 -0.565594
# 140068 -0.396476
# 140074  0.580664
# 140080 -1.957991
# 140086 -1.594989
# 140092  0.017940
# 140098 -0.904301
# 140104 -0.713037
# 140110 -0.442272
# 140116 -1.504903
# 140122 -0.148417
# 140128 -1.712495
# 140134 -0.721140
#
# [20020 rows x 5 columns]

# %%
toi_ts.query('term=="ham_betas"')

# %%
toi_ts['value_abs'] = np.abs(toi_ts.value)

# %%
null_dist = sorted(toi_ts.groupby('n').value_abs.max().values)

# %%
true_res =  toi_ts.query('n == 0')

# %%
true_res['all_term_all_roi_p'] = (len(null_dist) - np.searchsorted(null_dist,true_res.value_abs))/(len(null_dist) * 1.0)
# Out:
# /spin1/users/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
true_res.loc[:,['model','roi_path','term','all_term_all_roi_p']]
true_res['ROI'] = true_res.roi_path.str[:-7]
# Out:
# /spin1/users/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
true_res
# Out:
#         model  n                        roi_path               term     value  \
# 0         hce  0       LeftAntHippocampus.nii.gz          ham_betas  1.480078
# 1         hce  0       LeftMidHippocampus.nii.gz          ham_betas  2.903703
# 2         hce  0      LeftPostHippocampus.nii.gz          ham_betas  0.418204
# 3         hce  0   Left_Parahippocampal_G.nii.gz          ham_betas  2.228131
# 4         hce  0        Left_Posterior_V1.nii.gz          ham_betas  0.844220
# 5         hce  0      RightAntHippocampus.nii.gz          ham_betas  1.608104
# 6         hce  0      RightMidHippocampus.nii.gz          ham_betas  5.082741
# 7         hce  0     RightPostHippocampus.nii.gz          ham_betas  2.589052
# 8         hce  0  Right_Parahippocampal_G.nii.gz          ham_betas  2.382070
# 9         hce  0       Right_Posterior_V1.nii.gz          ham_betas  1.685936
# 10010   hcest  0       LeftAntHippocampus.nii.gz          ham_betas  1.386969
# 10011   hcest  0       LeftAntHippocampus.nii.gz   space:time_betas -2.776366
# 10012   hcest  0       LeftAntHippocampus.nii.gz        space_betas  3.257338
# 10013   hcest  0       LeftAntHippocampus.nii.gz         time_betas  2.731704
# 10014   hcest  0       LeftMidHippocampus.nii.gz          ham_betas  2.966345
# 10015   hcest  0       LeftMidHippocampus.nii.gz   space:time_betas -1.174588
# 10016   hcest  0       LeftMidHippocampus.nii.gz        space_betas  1.353190
# 10017   hcest  0       LeftMidHippocampus.nii.gz         time_betas  1.132742
# 10018   hcest  0      LeftPostHippocampus.nii.gz          ham_betas  0.412089
# 10019   hcest  0      LeftPostHippocampus.nii.gz   space:time_betas -0.221444
# 10020   hcest  0      LeftPostHippocampus.nii.gz        space_betas  0.103461
# 10021   hcest  0      LeftPostHippocampus.nii.gz         time_betas -0.003632
# 10022   hcest  0   Left_Parahippocampal_G.nii.gz          ham_betas  2.231149
# 10023   hcest  0   Left_Parahippocampal_G.nii.gz   space:time_betas -0.801834
# 10024   hcest  0   Left_Parahippocampal_G.nii.gz        space_betas  0.893761
# 10025   hcest  0   Left_Parahippocampal_G.nii.gz         time_betas  0.827870
# 10026   hcest  0        Left_Posterior_V1.nii.gz          ham_betas  0.853656
# 10027   hcest  0        Left_Posterior_V1.nii.gz   space:time_betas -0.740123
# 10028   hcest  0        Left_Posterior_V1.nii.gz        space_betas  0.516001
# 10029   hcest  0        Left_Posterior_V1.nii.gz         time_betas  0.612865
# ...       ... ..                             ...                ...       ...
# 80110  hvcest  0      RightAntHippocampus.nii.gz  ham:viv_ave_betas  0.241915
# 80111  hvcest  0      RightAntHippocampus.nii.gz          ham_betas  1.469204
# 80112  hvcest  0      RightAntHippocampus.nii.gz   space:time_betas -1.873871
# 80113  hvcest  0      RightAntHippocampus.nii.gz        space_betas  1.835173
# 80114  hvcest  0      RightAntHippocampus.nii.gz         time_betas  2.091156
# 80115  hvcest  0      RightAntHippocampus.nii.gz      viv_ave_betas -0.665562
# 80116  hvcest  0      RightMidHippocampus.nii.gz  ham:viv_ave_betas -1.278699
# 80117  hvcest  0      RightMidHippocampus.nii.gz          ham_betas  1.988997
# 80118  hvcest  0      RightMidHippocampus.nii.gz   space:time_betas  0.407117
# 80119  hvcest  0      RightMidHippocampus.nii.gz        space_betas -0.433049
# 80120  hvcest  0      RightMidHippocampus.nii.gz         time_betas -0.128055
# 80121  hvcest  0      RightMidHippocampus.nii.gz      viv_ave_betas  0.821640
# 80122  hvcest  0     RightPostHippocampus.nii.gz  ham:viv_ave_betas -1.926423
# 80123  hvcest  0     RightPostHippocampus.nii.gz          ham_betas  2.195709
# 80124  hvcest  0     RightPostHippocampus.nii.gz   space:time_betas -1.826187
# 80125  hvcest  0     RightPostHippocampus.nii.gz        space_betas  1.795308
# 80126  hvcest  0     RightPostHippocampus.nii.gz         time_betas  2.092722
# 80127  hvcest  0     RightPostHippocampus.nii.gz      viv_ave_betas  3.000215
# 80128  hvcest  0  Right_Parahippocampal_G.nii.gz  ham:viv_ave_betas -1.292187
# 80129  hvcest  0  Right_Parahippocampal_G.nii.gz          ham_betas  2.057347
# 80130  hvcest  0  Right_Parahippocampal_G.nii.gz   space:time_betas -1.738499
# 80131  hvcest  0  Right_Parahippocampal_G.nii.gz        space_betas  1.694632
# 80132  hvcest  0  Right_Parahippocampal_G.nii.gz         time_betas  1.635979
# 80133  hvcest  0  Right_Parahippocampal_G.nii.gz      viv_ave_betas -0.446283
# 80134  hvcest  0       Right_Posterior_V1.nii.gz  ham:viv_ave_betas -3.029674
# 80135  hvcest  0       Right_Posterior_V1.nii.gz          ham_betas  2.641590
# 80136  hvcest  0       Right_Posterior_V1.nii.gz   space:time_betas -1.445206
# 80137  hvcest  0       Right_Posterior_V1.nii.gz        space_betas  1.436299
# 80138  hvcest  0       Right_Posterior_V1.nii.gz         time_betas  1.282061
# 80139  hvcest  0       Right_Posterior_V1.nii.gz      viv_ave_betas  0.646422
#
#        value_abs  all_term_all_roi_p                      ROI
# 0       1.480078            1.000000       LeftAntHippocampus
# 1       2.903703            0.597403       LeftMidHippocampus
# 2       0.418204            1.000000      LeftPostHippocampus
# 3       2.228131            0.919081   Left_Parahippocampal_G
# 4       0.844220            1.000000        Left_Posterior_V1
# 5       1.608104            1.000000      RightAntHippocampus
# 6       5.082741            0.054945      RightMidHippocampus
# 7       2.589052            0.761239     RightPostHippocampus
# 8       2.382070            0.853147  Right_Parahippocampal_G
# 9       1.685936            0.998002       Right_Posterior_V1
# 10010   1.386969            1.000000       LeftAntHippocampus
# 10011   2.776366            0.671329       LeftAntHippocampus
# 10012   3.257338            0.426573       LeftAntHippocampus
# 10013   2.731704            0.694306       LeftAntHippocampus
# 10014   2.966345            0.561439       LeftMidHippocampus
# 10015   1.174588            1.000000       LeftMidHippocampus
# 10016   1.353190            1.000000       LeftMidHippocampus
# 10017   1.132742            1.000000       LeftMidHippocampus
# 10018   0.412089            1.000000      LeftPostHippocampus
# 10019   0.221444            1.000000      LeftPostHippocampus
# 10020   0.103461            1.000000      LeftPostHippocampus
# 10021   0.003632            1.000000      LeftPostHippocampus
# 10022   2.231149            0.916084   Left_Parahippocampal_G
# 10023   0.801834            1.000000   Left_Parahippocampal_G
# 10024   0.893761            1.000000   Left_Parahippocampal_G
# 10025   0.827870            1.000000   Left_Parahippocampal_G
# 10026   0.853656            1.000000        Left_Posterior_V1
# 10027   0.740123            1.000000        Left_Posterior_V1
# 10028   0.516001            1.000000        Left_Posterior_V1
# 10029   0.612865            1.000000        Left_Posterior_V1
# ...          ...                 ...                      ...
# 80110   0.241915            1.000000      RightAntHippocampus
# 80111   1.469204            1.000000      RightAntHippocampus
# 80112   1.873871            0.990010      RightAntHippocampus
# 80113   1.835173            0.991009      RightAntHippocampus
# 80114   2.091156            0.953047      RightAntHippocampus
# 80115   0.665562            1.000000      RightAntHippocampus
# 80116   1.278699            1.000000      RightMidHippocampus
# 80117   1.988997            0.975025      RightMidHippocampus
# 80118   0.407117            1.000000      RightMidHippocampus
# 80119   0.433049            1.000000      RightMidHippocampus
# 80120   0.128055            1.000000      RightMidHippocampus
# 80121   0.821640            1.000000      RightMidHippocampus
# 80122   1.926423            0.982018     RightPostHippocampus
# 80123   2.195709            0.926074     RightPostHippocampus
# 80124   1.826187            0.992008     RightPostHippocampus
# 80125   1.795308            0.993007     RightPostHippocampus
# 80126   2.092722            0.953047     RightPostHippocampus
# 80127   3.000215            0.550450     RightPostHippocampus
# 80128   1.292187            1.000000  Right_Parahippocampal_G
# 80129   2.057347            0.960040  Right_Parahippocampal_G
# 80130   1.738499            0.996004  Right_Parahippocampal_G
# 80131   1.694632            0.998002  Right_Parahippocampal_G
# 80132   1.635979            1.000000  Right_Parahippocampal_G
# 80133   0.446283            1.000000  Right_Parahippocampal_G
# 80134   3.029674            0.528472       Right_Posterior_V1
# 80135   2.641590            0.740260       Right_Posterior_V1
# 80136   1.445206            1.000000       Right_Posterior_V1
# 80137   1.436299            1.000000       Right_Posterior_V1
# 80138   1.282061            1.000000       Right_Posterior_V1
# 80139   0.646422            1.000000       Right_Posterior_V1
#
# [140 rows x 8 columns]

# %%
# betas is a nested dict {runs{rois{subjs{[number of perms x number of terms]}}}}
betas = {limits:{roi:{subj:[] for subj in subjects}for roi in lim_res[limits].keys()} for limits in lim_res.keys()}
for limits in lim_res.keys():
    #lim_res[limits] = {k:[] for k in roi_paths}
    for subj in subjects:
        #mask = nb.load(os.path.join(basedir,mask_pat%(subj,subj))).get_data()
        for roi_path in lim_res[limits].keys():
            betas[limits][roi_path][subj]=np.array(lim_res[limits][roi_path][subj])[:,:len(lim_dict[limits]['terms'])]

#real betas is a nested dict {runs{rois{[subjects x perms x terms]}}}
realbetas = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}
for limits in lim_dict.keys():
    #lim_res[limits] = {k:[] for k in roi_paths}
    for roi_path in lim_res[limits].keys():
        for subj in subjects:
            realbetas[limits][roi_path].append(betas[limits][roi_path][subj])

# %%
# calculate ps and come up with average betas across subjects

avbetas = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}

act_avbetas = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}
pcent_thresh = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}
permps = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}
permzs = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}

act_permps = {limit:{roi:[] for roi in lim_res[limit].keys()} for limit in lim_dict.keys()}

res_df = pd.DataFrame()
dfi=0
thresh =3
for limits in lim_dict.keys():
    #lim_res[limits] = {k:[] for k in roi_paths}
    for roi_path in lim_res[limits].keys():
        for subj in subjects:
            avbetas[limits][roi_path].append(betas[limits][roi_path][subj])
        act_avbetas[limits][roi_path]= np.average(avbetas[limits][roi_path],axis=0)
        avbetas[limits][roi_path]= stats.ttest_1samp(avbetas[limits][roi_path],0,axis=0)[0]
        #pcent_thresh[limits][roi_path] = np.percentile(np.abs(avbetas[limits][roi_path]),thresh-2,axis=0)
        act_permps[limits][roi_path] = (np.abs(act_avbetas[limits][roi_path][0])<= np.abs(act_avbetas[limits][roi_path])).sum(axis=0)/np.float(act_avbetas[limits][roi_path].shape[0])
        permps[limits][roi_path] = (np.abs(avbetas[limits][roi_path][0])<= np.abs(avbetas[limits][roi_path])).sum(axis=0)/np.float(avbetas[limits][roi_path].shape[0])
        permzs[limits][roi_path] = stats.norm.ppf(permps[limits][roi_path])

        beat_thresh = permps[limits][roi_path] < thresh

        if beat_thresh.sum()>0:
            for j in range(len(beat_thresh)):
                if beat_thresh[j] == True:
                    res_df.loc[dfi,'model'] = limits
                    res_df.loc[dfi,'ROI'] = roi_path[:-7]
                    res_df.loc[dfi,'Term'] = lim_dict[limits]['terms'][j]
                    res_df.loc[dfi,'p'] = permps[limits][roi_path][j]
                    res_df.loc[dfi,'t'] = avbetas[limits][roi_path][0][j]
                    res_df.loc[dfi,'actp'] = act_permps[limits][roi_path][j]
                    res_df.loc[dfi,'beta'] = act_avbetas[limits][roi_path][0][j]
                    print limits+'\t'+roi_path[:-7]+'\t'+lim_dict[limits]['terms'][j]+'\t%0.3g'%permps[limits][roi_path][j]+'\t%0.3g'%avbetas[limits][roi_path][0][j]+'\t%0.3g'%act_avbetas[limits][roi_path][0][j]#,pcent_thresh[limits][roi_path][beat_thresh]
                    dfi+=1
# Out:
# hvcest	Left_Posterior_V1	Intercept_betas	0.222	-1.28	-1.42
# hvcest	Left_Posterior_V1	correl_betas	0.807	-0.242	-0.0218
# hvcest	Left_Posterior_V1	event_betas	0.000999	9.87	0.23
# hvcest	Left_Posterior_V1	ham_betas	0.698	0.397	0.00372
# hvcest	Left_Posterior_V1	ham:viv_ave_betas	0.798	-0.241	-0.00296
# hvcest	Left_Posterior_V1	space_betas	0.376	0.912	0.296
# hvcest	Left_Posterior_V1	space:time_betas	0.272	-1.15	-0.066
# hvcest	Left_Posterior_V1	time_betas	0.335	1.01	0.192
# hvcest	RightPostHippocampus	ham_betas	0.0619	2.2	0.0139
# hvcest	RightPostHippocampus	ham:viv_ave_betas	0.0789	-1.93	-0.012
# hvcest	RightPostHippocampus	space_betas	0.106	1.8	0.194
# hvcest	RightPostHippocampus	space:time_betas	0.0999	-1.83	-0.037
# hvcest	RightPostHippocampus	time_betas	0.0679	2.09	0.162
# hvcest	RightPostHippocampus	viv_ave_betas	0.019	3	0.116
# hvcest	RightPostHippocampus	Intercept_tvals	0.00699	-3.76	-0.991
# hvcest	RightPostHippocampus	correl_tvals	0.969	0.0379	0.0154
# hvcest	RightPostHippocampus	event_tvals	0.000999	6.72	8.18
# hvcest	RightPostHippocampus	ham_tvals	0.043	2.46	1.07
# hvcest	RightPostHippocampus	ham:viv_ave_tvals	0.0779	-1.93	-0.543
# hvcest	RightPostHippocampus	space_tvals	0.102	1.88	0.346
# hvcest	RightPostHippocampus	space:time_tvals	0.104	-1.89	-0.391
# hvcest	RightPostHippocampus	time_tvals	0.0729	2.09	0.492
# hvcest	RightPostHippocampus	viv_ave_tvals	0.013	3.12	0.7
# hvcest	RightPostHippocampus	deviance	0.000999	9.08	2.58e+03
# hvcest	RightPostHippocampus	scale	0.998	187	0.969
# hvcest	RightPostHippocampus	llf	0.000999	-8.89	-3.75e+03
# hvcest	RightPostHippocampus	count	1	32.8	74.6
# hvcest	Right_Posterior_V1	Intercept_betas	0.135	-1.64	-2.04
# hvcest	Right_Posterior_V1	correl_betas	0.515	-0.743	-0.129
# hvcest	Right_Posterior_V1	event_betas	0.000999	10.8	0.184
# hvcest	Right_Posterior_V1	ham_betas	0.034	2.64	0.0229
# hvcest	Right_Posterior_V1	ham:viv_ave_betas	0.019	-3.03	-0.0184
# hvcest	Right_Posterior_V1	space_betas	0.178	1.44	0.459
# hvcest	Right_Posterior_V1	space:time_betas	0.183	-1.45	-0.0786
# hvcest	Right_Posterior_V1	time_betas	0.235	1.28	0.257
# hvcest	Right_Posterior_V1	viv_ave_betas	0.536	0.646	0.0584
# hvcest	Right_Posterior_V1	Intercept_tvals	0.144	-1.6	-0.86
# hvcest	Right_Posterior_V1	correl_tvals	0.494	-0.828	-0.844
# hvcest	Right_Posterior_V1	event_tvals	0.000999	7.66	4.3
# hvcest	Right_Posterior_V1	ham_tvals	0.027	2.66	1.65
# hvcest	Right_Posterior_V1	ham:viv_ave_tvals	0.015	-3.17	-0.873
# hvcest	Right_Posterior_V1	space_tvals	0.181	1.41	0.668
# hvcest	Right_Posterior_V1	space:time_tvals	0.184	-1.42	-0.682
# hvcest	Right_Posterior_V1	time_tvals	0.253	1.23	0.644
# hvcest	Right_Posterior_V1	viv_ave_tvals	0.55	0.615	0.323
# hvcest	Right_Posterior_V1	deviance	0.0839	8.83	2.59e+03
# hvcest	Right_Posterior_V1	scale	0.578	213	0.97
# hvcest	Right_Posterior_V1	llf	0.0869	-8.8	-3.76e+03
# hvcest	Right_Posterior_V1	count	1	21.9	95
# hvcest	LeftAntHippocampus	Intercept_betas	0.002	-5.42	-2.29
# hvcest	LeftAntHippocampus	correl_betas	0.238	1.29	0.0899
# hvcest	LeftMidHippocampus	scale	1	149	0.967
# hvcest	LeftMidHippocampus	llf	0.998	-8.71	-3.75e+03
# hvcest	LeftMidHippocampus	count	1	24.3	64
# hvce	Left_Posterior_V1	Intercept_betas	0.00699	-3.64	-0.612
# hvce	Left_Posterior_V1	correl_betas	0.883	-0.155	-0.014
# hvce	Left_Posterior_V1	event_betas	0.000999	9.88	0.231
# hvce	Left_Posterior_V1	ham_betas	0.762	0.306	0.00296
# hvce	Left_Posterior_V1	ham:viv_ave_betas	0.873	-0.168	-0.00219
# hvce	Left_Posterior_V1	viv_ave_betas	0.436	-0.846	-0.0775
# hvce	Left_Posterior_V1	Intercept_tvals	0.003	-3.73	-1.82
# hvce	Left_Posterior_V1	correl_tvals	0.686	-0.461	-0.192
# hvce	Left_Posterior_V1	event_tvals	0.000999	7.2	5.39
# hvce	Left_Posterior_V1	ham_tvals	0.622	0.523	0.301
# hvce	Left_Posterior_V1	ham:viv_ave_tvals	0.868	-0.171	-0.0922
# hvce	Left_Posterior_V1	viv_ave_tvals	0.348	-1.03	-0.502
# hvce	Left_Posterior_V1	deviance	0.578	8.74	2.62e+03
# hvce	Left_Posterior_V1	scale	0.858	258	0.979
# hvce	Left_Posterior_V1	llf	0.579	-8.77	-3.77e+03
# hvce	Left_Posterior_V1	count	1	41.6	73.1
# hvce	Right_Parahippocampal_G	Intercept_betas	0.000999	-10.3	-1.28
# hvce	Right_Parahippocampal_G	correl_betas	0.195	1.35	0.0755
# hvce	Right_Parahippocampal_G	event_betas	0.000999	15.5	0.396
# hvce	Right_Parahippocampal_G	ham_betas	0.0799	1.98	0.0192
# hvce	Right_Parahippocampal_G	ham:viv_ave_betas	0.267	-1.25	-0.0172
# hvce	Right_Parahippocampal_G	viv_ave_betas	0.643	-0.491	-0.0447
# hvce	Right_Parahippocampal_G	Intercept_tvals	0.000999	-6.41	-4.16
# hvce	Right_Parahippocampal_G	correl_tvals	0.242	1.24	0.3
# hvce	Right_Parahippocampal_G	event_tvals	0.000999	9.64	9.35
# hvce	Right_Parahippocampal_G	ham_tvals	0.0649	2.05	1.41
# hvce	Right_Parahippocampal_G	ham:viv_ave_tvals	0.226	-1.37	-0.826
# hvce	Right_Parahippocampal_G	viv_ave_tvals	0.682	-0.422	-0.213
# hvce	Right_Parahippocampal_G	deviance	0.000999	8.96	2.54e+03
# hvce	Right_Parahippocampal_G	scale	0.967	211	0.954
# hvce	Right_Parahippocampal_G	llf	0.002	-8.84	-3.73e+03
# hvce	Right_Parahippocampal_G	count	1	37.5	289
# hvce	LeftPostHippocampus	Intercept_betas	0.000999	-10.1	-0.957
# hvce	LeftPostHippocampus	correl_betas	0.695	0.449	0.0338
# hvce	LeftPostHippocampus	event_betas	0.000999	11.2	0.29
# hvce	LeftPostHippocampus	ham_betas	0.389	0.876	0.00476
# hvce	LeftPostHippocampus	ham:viv_ave_betas	0.542	-0.633	-0.00507
# hvce	LeftPostHippocampus	viv_ave_betas	0.0669	2.2	0.142
# hvce	LeftPostHippocampus	Intercept_tvals	0.000999	-8	-2.99
# hvce	LeftPostHippocampus	correl_tvals	0.709	0.458	0.156
# hvce	LeftPostHippocampus	event_tvals	0.000999	8.95	6.65
# hvce	LeftPostHippocampus	ham_tvals	0.391	0.848	0.326
# hvce	LeftPostHippocampus	ham:viv_ave_tvals	0.533	-0.64	-0.238
# hvce	LeftPostHippocampus	viv_ave_tvals	0.0889	2.05	0.852
# hvce	LeftPostHippocampus	deviance	0.801	8.72	2.62e+03
# hvce	LeftPostHippocampus	scale	0.922	294	0.978
# hvce	LeftPostHippocampus	llf	0.776	-8.76	-3.77e+03
# hvce	LeftPostHippocampus	count	1	34.8	70.9
# hvce	RightMidHippocampus	Intercept_betas	0.000999	-9.39	-0.951
# hvce	RightMidHippocampus	correl_betas	0.793	0.291	0.0213
# hvce	RightMidHippocampus	event_betas	0.000999	7.82	0.285
# hvce	RightMidHippocampus	ham_betas	0.0589	2.17	0.0169
# hvce	RightMidHippocampus	ham:viv_ave_betas	0.228	-1.32	-0.0148
# hvce	RightMidHippocampus	viv_ave_betas	0.566	0.614	0.0426
# hvce	RightMidHippocampus	Intercept_tvals	0.002	-6.6	-3.07
# hvce	RightMidHippocampus	correl_tvals	0.789	0.268	0.104
# hvce	RightMidHippocampus	event_tvals	0.002	6.41	6.63
# hvce	RightMidHippocampus	ham_tvals	0.045	2.35	1.37
# hvce	RightMidHippocampus	ham:viv_ave_tvals	0.261	-1.21	-0.652
# hvce	RightMidHippocampus	viv_ave_tvals	0.557	0.611	0.264
# hvce	RightMidHippocampus	deviance	0.041	8.82	2.61e+03
# hvce	RightMidHippocampus	scale	0.996	212	0.976
# hvce	RightMidHippocampus	llf	0.031	-8.8	-3.76e+03
# hvce	RightMidHippocampus	count	1	38.9	75.4
# hvce	RightPostHippocampus	Intercept_betas	0.000999	-5.58	-1.05
# hvce	RightPostHippocampus	correl_betas	0.764	-0.35	-0.0269
# hvce	RightPostHippocampus	event_betas	0.000999	10.6	0.343
# hvce	RightPostHippocampus	ham_betas	0.0939	1.98	0.0132
# hvce	RightPostHippocampus	ham:viv_ave_betas	0.127	-1.65	-0.011
# hvce	RightPostHippocampus	viv_ave_betas	0.02	2.91	0.113
# hvce	RightPostHippocampus	Intercept_tvals	0.005	-3.86	-3.6
# hvce	RightPostHippocampus	correl_tvals	0.951	0.0856	0.0347
# hvce	RightPostHippocampus	event_tvals	0.000999	6.74	8.17
# hvce	RightPostHippocampus	ham_tvals	0.05	2.29	1.03
# hvce	RightPostHippocampus	ham:viv_ave_tvals	0.121	-1.68	-0.5
# hvce	RightPostHippocampus	viv_ave_tvals	0.017	3.02	0.685
# hvce	RightPostHippocampus	deviance	0.000999	9.11	2.58e+03
# hvce	RightPostHippocampus	scale	0.998	182	0.97
# hvce	RightPostHippocampus	llf	0.000999	-8.9	-3.75e+03
# hvce	RightPostHippocampus	count	1	32.8	74.6
# hvce	Right_Posterior_V1	Intercept_betas	0.00599	-3.61	-0.552
# hvce	Right_Posterior_V1	correl_betas	0.534	-0.718	-0.126
# hvce	Right_Posterior_V1	event_betas	0.000999	11.3	0.186
# hvce	Right_Posterior_V1	ham_betas	0.029	2.65	0.0225
# hvce	Right_Posterior_V1	ham:viv_ave_betas	0.025	-2.86	-0.0177
# hvce	Right_Posterior_V1	viv_ave_betas	0.623	0.484	0.0402
# hvce	Right_Posterior_V1	Intercept_tvals	0.00799	-2.96	-1.55
# hvce	Right_Posterior_V1	correl_tvals	0.5	-0.812	-0.833
# hvce	Right_Posterior_V1	event_tvals	0.000999	7.9	4.33
# hvce	Right_Posterior_V1	ham_tvals	0.028	2.69	1.62
# hvce	Right_Posterior_V1	ham:viv_ave_tvals	0.019	-3.03	-0.828
# hvce	Right_Posterior_V1	viv_ave_tvals	0.653	0.457	0.227
# hvce	Right_Posterior_V1	deviance	0.00799	8.99	2.62e+03
# hvce	Right_Posterior_V1	scale	0.764	223	0.983
# hvce	Right_Posterior_V1	llf	0.00999	-8.85	-3.77e+03
# hvce	Right_Posterior_V1	count	1	21.9	95
# hvce	LeftAntHippocampus	Intercept_betas	0.000999	-10	-1.1
# hvce	LeftAntHippocampus	correl_betas	0.267	1.19	0.0825
# hvce	LeftAntHippocampus	event_betas	0.000999	15.6	0.315
# hvce	LeftAntHippocampus	ham_betas	0.305	1.12	0.00365
# hvce	LeftAntHippocampus	ham:viv_ave_betas	0.694	0.459	0.00331
# hvce	LeftAntHippocampus	viv_ave_betas	0.179	1.6	0.08
# hvce	LeftAntHippocampus	Intercept_tvals	0.000999	-9.73	-3.41
# hvce	LeftAntHippocampus	correl_tvals	0.231	1.27	0.352
# hvce	LeftAntHippocampus	event_tvals	0.000999	12.4	7.27
# hvce	LeftAntHippocampus	ham_tvals	0.334	1.03	0.237
# hvce	LeftAntHippocampus	ham:viv_ave_tvals	0.716	0.418	0.14
# hvce	LeftAntHippocampus	viv_ave_tvals	0.208	1.45	0.446
# hvce	LeftAntHippocampus	deviance	0.935	8.71	2.6e+03
# hvce	LeftAntHippocampus	scale	0.981	292	0.973
# hvce	LeftAntHippocampus	llf	0.934	-8.76	-3.76e+03
# hvce	LeftAntHippocampus	count	1	35.9	127
# hvce	RightAntHippocampus	Intercept_betas	0.000999	-6.11	-1
# hvce	RightAntHippocampus	correl_betas	0.755	0.344	0.0372
# hvce	RightAntHippocampus	event_betas	0.000999	7.23	0.321
# hvce	RightAntHippocampus	ham_betas	0.191	1.46	0.00885
# hvce	RightAntHippocampus	ham:viv_ave_betas	0.863	0.194	0.00272
# hvce	RightAntHippocampus	viv_ave_betas	0.534	-0.686	-0.0931
# hvce	RightAntHippocampus	Intercept_tvals	0.000999	-5.09	-3.33
# hvce	RightAntHippocampus	correl_tvals	0.788	0.295	0.163
# hvce	RightAntHippocampus	event_tvals	0.000999	5.5	7.76
# hvce	RightAntHippocampus	ham_tvals	0.213	1.38	0.615
# hvce	RightAntHippocampus	ham:viv_ave_tvals	0.89	0.139	0.0822
# hvce	RightAntHippocampus	viv_ave_tvals	0.53	-0.707	-0.543
# hvce	RightAntHippocampus	deviance	0.000999	9.03	2.57e+03
# hvce	RightAntHippocampus	scale	1	143	0.965
# hvce	RightAntHippocampus	llf	0.000999	-8.87	-3.75e+03
# hvce	RightAntHippocampus	count	1	38	121
# hvce	Left_Parahippocampal_G	Intercept_betas	0.000999	-9.67	-1.24
# hvce	Left_Parahippocampal_G	correl_betas	0.565	0.58	0.0421
# hvce	Left_Parahippocampal_G	event_betas	0.000999	12.9	0.408
# hvce	Left_Parahippocampal_G	ham_betas	0.277	1.23	0.014
# hvce	Left_Parahippocampal_G	ham:viv_ave_betas	0.632	-0.542	-0.00717
# hvce	Left_Parahippocampal_G	viv_ave_betas	0.309	-1.1	-0.104
# hvce	Left_Parahippocampal_G	Intercept_tvals	0.000999	-6.38	-4.05
# hvce	Left_Parahippocampal_G	correl_tvals	0.429	0.843	0.278
# hvce	Left_Parahippocampal_G	event_tvals	0.000999	11.4	9.44
# hvce	Left_Parahippocampal_G	ham_tvals	0.287	1.19	1
# hvce	Left_Parahippocampal_G	ham:viv_ave_tvals	0.588	-0.645	-0.424
# hvce	Left_Parahippocampal_G	viv_ave_tvals	0.392	-0.926	-0.545
# hvce	Left_Parahippocampal_G	deviance	0.295	8.8	2.54e+03
# hvce	Left_Parahippocampal_G	scale	0.996	147	0.952
# hvce	Left_Parahippocampal_G	llf	0.242	-8.79	-3.73e+03
# hvce	Left_Parahippocampal_G	count	1	40.2	320
# hvce	LeftMidHippocampus	Intercept_betas	0.000999	-8.88	-1.13
# hvce	LeftMidHippocampus	correl_betas	0.572	0.609	0.052
# hvce	LeftMidHippocampus	event_betas	0.000999	6.67	0.302
# hvce	LeftMidHippocampus	ham_betas	0.003	3.66	0.0204
# hvce	LeftMidHippocampus	ham:viv_ave_betas	0.425	-0.804	-0.00879
# hvce	LeftMidHippocampus	viv_ave_betas	0.123	1.61	0.165
# hvce	LeftMidHippocampus	Intercept_tvals	0.000999	-8.2	-3.49
# hvce	LeftMidHippocampus	correl_tvals	0.619	0.565	0.214
# hvce	LeftMidHippocampus	event_tvals	0.000999	6.72	6.92
# hvce	LeftMidHippocampus	ham_tvals	0.004	3.71	1.5
# hvce	LeftMidHippocampus	ham:viv_ave_tvals	0.382	-0.873	-0.439
# hvce	LeftMidHippocampus	viv_ave_tvals	0.131	1.6	1.02
# hvce	LeftMidHippocampus	deviance	1	8.57	2.59e+03
# hvce	LeftMidHippocampus	scale	1	159	0.969
# hvce	LeftMidHippocampus	llf	1	-8.71	-3.76e+03
# hvce	LeftMidHippocampus	count	1	24.3	64
# hcest	Left_Posterior_V1	Intercept_betas	0.341	-0.959	-1.09
# hcest	Left_Posterior_V1	correl_betas	0.723	-0.381	-0.0363
# hcest	Left_Posterior_V1	event_betas	0.000999	9.92	0.231
# hcest	Left_Posterior_V1	ham_betas	0.428	0.854	0.00342
# hcest	Left_Posterior_V1	space_betas	0.607	0.516	0.167
# hcest	Left_Posterior_V1	space:time_betas	0.456	-0.74	-0.0426
# hcest	Left_Posterior_V1	time_betas	0.56	0.613	0.12
# hcest	Left_Posterior_V1	Intercept_tvals	0.412	-0.875	-0.443
# hcest	Left_Posterior_V1	correl_tvals	0.554	-0.657	-0.295
# hcest	LeftPostHippocampus	llf	0.933	-8.75	-3.77e+03
# hcest	LeftPostHippocampus	count	1	34.8	70.9
# hcest	RightMidHippocampus	Intercept_betas	0.454	-0.776	-0.66
# hcest	RightMidHippocampus	correl_betas	0.807	0.275	0.0206
# hcest	RightMidHippocampus	event_betas	0.002	7.85	0.286
# hcest	RightMidHippocampus	ham_betas	0.002	4.1	0.011
# hcest	RightMidHippocampus	space_betas	0.537	-0.627	-0.161
# hcest	RightMidHippocampus	space:time_betas	0.575	0.591	0.0289
# hcest	RightMidHippocampus	time_betas	0.766	-0.298	-0.0493
# hcest	RightMidHippocampus	Intercept_tvals	0.337	-1.02	-0.499
# hcest	RightMidHippocampus	correl_tvals	0.782	0.284	0.111
# hcest	RightMidHippocampus	event_tvals	0.002	6.41	6.67
# hcest	RightMidHippocampus	ham_tvals	0.002	4.1	1.44
# hcest	RightMidHippocampus	space_tvals	0.96	-0.0465	-0.0226
# hcest	RightMidHippocampus	space:time_tvals	0.994	0.0119	0.0058
# hcest	RightMidHippocampus	time_tvals	0.889	0.128	0.0612
# hcest	RightMidHippocampus	deviance	0.447	8.74	2.6e+03
# hcest	RightMidHippocampus	scale	0.999	168	0.972
# hcest	RightMidHippocampus	llf	0.395	-8.77	-3.76e+03
# hcest	RightMidHippocampus	count	1	38.9	75.4
# hcest	RightPostHippocampus	Intercept_betas	0.00699	-3.61	-1.78
# hcest	RightPostHippocampus	correl_betas	0.752	-0.387	-0.0315
# hcest	RightPostHippocampus	event_betas	0.000999	10.5	0.343
# hcest	RightPostHippocampus	ham_betas	0.041	2.55	0.00846
# hcest	RightPostHippocampus	space_betas	0.19	1.44	0.17
# hcest	RightPostHippocampus	space:time_betas	0.17	-1.54	-0.0338
# hcest	RightPostHippocampus	time_betas	0.0979	1.88	0.154
# hcest	RightPostHippocampus	Intercept_tvals	0.011	-3.44	-0.928
# hcest	RightPostHippocampus	correl_tvals	0.952	0.0644	0.0278
# hcest	RightPostHippocampus	event_tvals	0.000999	6.73	8.18
# hcest	RightPostHippocampus	ham_tvals	0.038	2.58	1.14
# hcest	RightPostHippocampus	space_tvals	0.163	1.54	0.306
# hcest	RightPostHippocampus	space:time_tvals	0.15	-1.63	-0.361
# hcest	RightPostHippocampus	time_tvals	0.0979	1.9	0.469
# hcest	RightPostHippocampus	deviance	0.000999	9.1	2.58e+03
# hcest	RightPostHippocampus	scale	1	187	0.969
# hcest	RightPostHippocampus	llf	0.000999	-8.89	-3.75e+03
# hcest	RightPostHippocampus	count	1	32.8	74.6
# hcest	Right_Posterior_V1	Intercept_betas	0.187	-1.42	-1.86
# hcest	Right_Posterior_V1	correl_betas	0.503	-0.75	-0.128
# hcest	Right_Posterior_V1	event_betas	0.000999	10.7	0.185
# hcest	Right_Posterior_V1	ham_betas	0.132	1.6	0.0109
# hcest	Right_Posterior_V1	space_betas	0.25	1.24	0.421
# hcest	Right_Posterior_V1	space:time_betas	0.248	-1.26	-0.0727
# hcest	Right_Posterior_V1	time_betas	0.327	1.11	0.237
# hcest	Right_Posterior_V1	Intercept_tvals	0.215	-1.34	-0.773
# hcest	Right_Posterior_V1	correl_tvals	0.485	-0.83	-0.832
# hcest	Right_Posterior_V1	event_tvals	0.000999	7.67	4.32
# hcest	Right_Posterior_V1	ham_tvals	0.114	1.7	1.59
# hcest	Right_Posterior_V1	space_tvals	0.265	1.19	0.606
# hcest	Right_Posterior_V1	space:time_tvals	0.257	-1.23	-0.627
# hcest	Right_Posterior_V1	time_tvals	0.334	1.05	0.585
# hcest	Right_Posterior_V1	deviance	0.409	8.72	2.61e+03
# hcest	Right_Posterior_V1	scale	0.859	227	0.975
# hcest	Right_Posterior_V1	llf	0.406	-8.76	-3.76e+03
# hcest	Right_Posterior_V1	count	1	21.9	95
# hcest	LeftAntHippocampus	Intercept_betas	0.002	-5.37	-2.32
# hcest	LeftAntHippocampus	correl_betas	0.185	1.45	0.0987
# hcest	LeftAntHippocampus	event_betas	0.000999	15.2	0.315
# hcest	LeftAntHippocampus	ham_betas	0.227	1.39	0.00524
# hcest	LeftAntHippocampus	space_betas	0.015	3.26	0.42
# hcest	LeftAntHippocampus	space:time_betas	0.024	-2.78	-0.0642
# hcest	LeftAntHippocampus	time_betas	0.021	2.73	0.187
# hcest	LeftAntHippocampus	Intercept_tvals	0.002	-5.26	-1.16
# hcest	LeftAntHippocampus	correl_tvals	0.131	1.62	0.431
# hcest	LeftAntHippocampus	event_tvals	0.000999	11.9	7.26
# hcest	LeftAntHippocampus	ham_tvals	0.225	1.36	0.723
# hcest	LeftAntHippocampus	space_tvals	0.00899	3.57	0.737
# hcest	LeftAntHippocampus	space:time_tvals	0.013	-3.22	-0.656
# hcest	LeftAntHippocampus	time_tvals	0.013	3.11	0.574
# hcest	LeftAntHippocampus	deviance	0.892	8.71	2.6e+03
# hcest	LeftAntHippocampus	scale	0.997	279	0.974
# hcest	LeftAntHippocampus	llf	0.885	-8.76	-3.76e+03
# hcest	LeftAntHippocampus	count	1	35.9	127
# hcest	RightAntHippocampus	Intercept_betas	0.04	-2.43	-2.85
# hcest	RightAntHippocampus	correl_betas	0.831	0.234	0.027
# hcest	RightAntHippocampus	event_betas	0.000999	7.22	0.321
# hcest	RightAntHippocampus	ham_betas	0.16	1.59	0.00812
# hcest	RightAntHippocampus	space_betas	0.176	1.39	0.477
# hcest	RightAntHippocampus	space:time_betas	0.175	-1.38	-0.0772
# hcest	RightAntHippocampus	time_betas	0.136	1.55	0.297
# hcest	RightAntHippocampus	Intercept_tvals	0.036	-2.53	-1.21
# hcest	RightAntHippocampus	correl_tvals	0.852	0.196	0.115
# hcest	RightAntHippocampus	event_tvals	0.000999	5.52	7.74
# hcest	RightAntHippocampus	ham_tvals	0.148	1.64	1.1
# hcest	RightAntHippocampus	space_tvals	0.272	1.12	0.55
# hcest	RightAntHippocampus	space:time_tvals	0.295	-1.07	-0.51
# hcest	RightAntHippocampus	time_tvals	0.188	1.34	0.658
# hcest	RightAntHippocampus	deviance	0.000999	9.06	2.58e+03
# hcest	RightAntHippocampus	scale	0.995	183	0.969
# hcest	RightAntHippocampus	llf	0.000999	-8.88	-3.75e+03
# hcest	RightAntHippocampus	count	1	38	121
# hcest	Left_Parahippocampal_G	Intercept_betas	0.05	-2.2	-2.23
# hcest	Left_Parahippocampal_G	correl_betas	0.571	0.57	0.043
# hcest	Left_Parahippocampal_G	event_betas	0.000999	13.3	0.41
# hcest	Left_Parahippocampal_G	ham_betas	0.05	2.23	0.00924
# hcest	Left_Parahippocampal_G	space_betas	0.424	0.894	0.316
# hcest	Left_Parahippocampal_G	space:time_betas	0.47	-0.802	-0.0517
# hcest	Left_Parahippocampal_G	time_betas	0.456	0.828	0.156
# hcest	Left_Parahippocampal_G	Intercept_tvals	0.034	-2.55	-1.07
# hcest	Left_Parahippocampal_G	correl_tvals	0.428	0.841	0.298
# hcest	Left_Parahippocampal_G	event_tvals	0.000999	11.6	9.47
# hcest	Left_Parahippocampal_G	ham_tvals	0.0529	2.2	1.29
# hcest	Left_Parahippocampal_G	space_tvals	0.295	1.1	0.542
# hcest	Left_Parahippocampal_G	space:time_tvals	0.348	-1.03	-0.524
# hcest	Left_Parahippocampal_G	time_tvals	0.383	0.937	0.427
# hcest	Left_Parahippocampal_G	deviance	0.975	8.65	2.55e+03
# hcest	Left_Parahippocampal_G	scale	0.997	159	0.955
# hcest	Left_Parahippocampal_G	llf	0.97	-8.73	-3.74e+03
# hcest	Left_Parahippocampal_G	count	1	40.2	320
# hcest	LeftMidHippocampus	Intercept_betas	0.03	-2.62	-2.01
# hcest	LeftMidHippocampus	correl_betas	0.503	0.728	0.064
# hcest	LeftMidHippocampus	event_betas	0.000999	6.64	0.3
# hcest	LeftMidHippocampus	ham_betas	0.02	2.97	0.0149
# hcest	LeftMidHippocampus	space_betas	0.204	1.35	0.321
# hcest	LeftMidHippocampus	space:time_betas	0.269	-1.17	-0.0503
# hcest	LeftMidHippocampus	time_betas	0.291	1.13	0.149
# hcest	LeftMidHippocampus	Intercept_tvals	0.023	-2.82	-0.932
# hcest	LeftMidHippocampus	correl_tvals	0.523	0.715	0.281
# hcest	LeftMidHippocampus	event_tvals	0.000999	6.65	6.89
# hcest	LeftMidHippocampus	ham_tvals	0.011	3.32	1.94
# hcest	LeftMidHippocampus	space_tvals	0.264	1.18	0.422
# hcest	LeftMidHippocampus	space:time_tvals	0.348	-0.983	-0.368
# hcest	LeftMidHippocampus	time_tvals	0.284	1.13	0.372
# hcest	LeftMidHippocampus	deviance	1	8.57	2.6e+03
# hcest	LeftMidHippocampus	scale	1	158	0.97
# hcest	LeftMidHippocampus	llf	1	-8.71	-3.76e+03
# hcest	LeftMidHippocampus	count	1	24.3	64
# hce	Left_Posterior_V1	Intercept_betas	0.000999	-5.63	-0.667
# hce	Left_Posterior_V1	correl_betas	0.776	-0.291	-0.0277
# hce	Left_Posterior_V1	event_betas	0.000999	9.84	0.232
# hce	Left_Posterior_V1	ham_betas	0.429	0.844	0.00319
# hce	Left_Posterior_V1	Intercept_tvals	0.000999	-5.8	-2.1
# hce	Left_Posterior_V1	correl_tvals	0.599	-0.575	-0.258
# hce	Left_Posterior_V1	event_tvals	0.000999	7.18	5.39
# hce	Left_Posterior_V1	ham_tvals	0.409	0.891	0.431
# hce	Left_Posterior_V1	deviance	0.015	8.84	2.64e+03
# hce	Left_Posterior_V1	scale	0.997	386	0.987
# hce	Left_Posterior_V1	llf	0.016	-8.8	-3.78e+03
# hce	Left_Posterior_V1	count	1	41.6	73.1
# hce	Right_Parahippocampal_G	Intercept_betas	0.000999	-14.4	-1.3
# hce	Right_Parahippocampal_G	correl_betas	0.265	1.19	0.0669
# hce	Right_Parahippocampal_G	event_betas	0.000999	15.5	0.397
# hce	Right_Parahippocampal_G	ham_betas	0.034	2.38	0.0102
# hce	Right_Parahippocampal_G	Intercept_tvals	0.000999	-7.57	-4.41
# hce	Right_Parahippocampal_G	correl_tvals	0.335	1.04	0.251
# hce	Right_Parahippocampal_G	event_tvals	0.000999	9.61	9.36
# hce	Right_Parahippocampal_G	ham_tvals	0.024	2.51	1.59
# hce	Right_Parahippocampal_G	deviance	0.000999	8.99	2.56e+03
# hce	Right_Parahippocampal_G	scale	1	190	0.961
# hce	Right_Parahippocampal_G	llf	0.000999	-8.85	-3.74e+03
# hce	Right_Parahippocampal_G	count	1	37.5	289
# hce	LeftPostHippocampus	Intercept_betas	0.000999	-10.6	-0.873
# hce	LeftPostHippocampus	correl_betas	0.676	0.465	0.035
# hce	LeftPostHippocampus	event_betas	0.000999	11.2	0.288
# hce	LeftPostHippocampus	ham_betas	0.679	0.418	0.0018
# hce	LeftPostHippocampus	Intercept_tvals	0.000999	-9.06	-2.85
# hce	LeftPostHippocampus	correl_tvals	0.707	0.466	0.159
# hce	LeftPostHippocampus	event_tvals	0.000999	8.89	6.62
# hce	LeftPostHippocampus	ham_tvals	0.499	0.699	0.364
# hce	LeftPostHippocampus	deviance	0.996	8.73	2.62e+03
# hce	LeftPostHippocampus	scale	0.999	291	0.981
# hce	LeftPostHippocampus	llf	0.988	-8.76	-3.77e+03
# hce	LeftPostHippocampus	count	1	34.8	70.9
# hce	RightMidHippocampus	Intercept_betas	0.000999	-9.85	-0.941
# hce	RightMidHippocampus	correl_betas	0.81	0.268	0.0197
# hce	RightMidHippocampus	event_betas	0.000999	7.85	0.286
# hce	RightMidHippocampus	ham_betas	0.002	5.08	0.012
# hce	RightMidHippocampus	Intercept_tvals	0.000999	-6.67	-3.2
# hce	RightMidHippocampus	correl_tvals	0.798	0.255	0.0992
# hce	RightMidHippocampus	event_tvals	0.002	6.42	6.65
# hce	RightMidHippocampus	ham_tvals	0.002	5.05	1.55
# hce	RightMidHippocampus	deviance	0.002	8.83	2.61e+03
# hce	RightMidHippocampus	scale	1	216	0.978
# hce	RightMidHippocampus	llf	0.002	-8.8	-3.77e+03
# hce	RightMidHippocampus	count	1	38.9	75.4
# hce	RightPostHippocampus	Intercept_betas	0.002	-5.3	-0.979
# hce	RightPostHippocampus	correl_betas	0.783	-0.325	-0.0264
# hce	RightPostHippocampus	event_betas	0.000999	10.6	0.343
# hce	RightPostHippocampus	ham_betas	0.035	2.59	0.00851
# hce	RightPostHippocampus	Intercept_tvals	0.013	-3.5	-3.64
# hce	RightPostHippocampus	correl_tvals	0.913	0.12	0.052
# hce	RightPostHippocampus	event_tvals	0.000999	6.73	8.17
# hce	RightPostHippocampus	ham_tvals	0.037	2.63	1.15
# hce	RightPostHippocampus	deviance	0.000999	9.13	2.59e+03
# hce	RightPostHippocampus	scale	1	177	0.971
# hce	RightPostHippocampus	llf	0.000999	-8.9	-3.75e+03
# hce	RightPostHippocampus	count	1	32.8	74.6
# hce	Right_Posterior_V1	Intercept_betas	0.015	-3.03	-0.512
# hce	Right_Posterior_V1	correl_betas	0.539	-0.71	-0.122
# hce	Right_Posterior_V1	event_betas	0.000999	11.2	0.187
# hce	Right_Posterior_V1	ham_betas	0.111	1.69	0.0111
# hce	Right_Posterior_V1	Intercept_tvals	0.043	-2.14	-1.41
# hce	Right_Posterior_V1	correl_tvals	0.498	-0.803	-0.809
# hce	Right_Posterior_V1	event_tvals	0.000999	7.9	4.34
# hce	Right_Posterior_V1	ham_tvals	0.0939	1.78	1.6
# hce	Right_Posterior_V1	deviance	0.017	8.87	2.63e+03
# hce	Right_Posterior_V1	scale	0.991	268	0.986
# hce	Right_Posterior_V1	llf	0.018	-8.81	-3.78e+03
# hce	Right_Posterior_V1	count	1	21.9	95
# hce	LeftAntHippocampus	Intercept_betas	0.000999	-9.99	-1.07
# hce	LeftAntHippocampus	correl_betas	0.225	1.34	0.0911
# hce	LeftAntHippocampus	event_betas	0.000999	15.5	0.313
# hce	LeftAntHippocampus	ham_betas	0.194	1.48	0.00589
# hce	LeftAntHippocampus	Intercept_tvals	0.000999	-8.61	-3.51
# hce	LeftAntHippocampus	correl_tvals	0.171	1.47	0.395
# hce	LeftAntHippocampus	event_tvals	0.000999	12.1	7.22
# hce	LeftAntHippocampus	ham_tvals	0.203	1.45	0.808
# hce	LeftAntHippocampus	deviance	0.998	8.73	2.61e+03
# hce	LeftAntHippocampus	scale	1	301	0.976
# hce	LeftAntHippocampus	llf	0.998	-8.76	-3.77e+03
# hce	LeftAntHippocampus	count	1	35.9	127
# hce	RightAntHippocampus	Intercept_betas	0.000999	-7.45	-1.04
# hce	RightAntHippocampus	correl_betas	0.827	0.248	0.028
# hce	RightAntHippocampus	event_betas	0.000999	7.23	0.322
# hce	RightAntHippocampus	ham_betas	0.16	1.61	0.0081
# hce	RightAntHippocampus	Intercept_tvals	0.000999	-5.83	-3.61
# hce	RightAntHippocampus	correl_tvals	0.861	0.189	0.111
# hce	RightAntHippocampus	event_tvals	0.000999	5.52	7.77
# hce	RightAntHippocampus	ham_tvals	0.15	1.64	1.1
# hce	RightAntHippocampus	deviance	0.000999	9.1	2.59e+03
# hce	RightAntHippocampus	scale	1	170	0.972
# hce	RightAntHippocampus	llf	0.000999	-8.89	-3.75e+03
# hce	RightAntHippocampus	count	1	38	121
# hce	Left_Parahippocampal_G	Intercept_betas	0.000999	-10.8	-1.28
# hce	Left_Parahippocampal_G	correl_betas	0.558	0.579	0.043
# hce	Left_Parahippocampal_G	event_betas	0.000999	13.1	0.409
# hce	Left_Parahippocampal_G	ham_betas	0.049	2.23	0.00927
# hce	Left_Parahippocampal_G	Intercept_tvals	0.000999	-7.52	-4.36
# hce	Left_Parahippocampal_G	correl_tvals	0.42	0.854	0.293
# hce	Left_Parahippocampal_G	event_tvals	0.000999	11.5	9.45
# hce	Left_Parahippocampal_G	ham_tvals	0.046	2.22	1.3
# hce	Left_Parahippocampal_G	deviance	1	8.67	2.57e+03
# hce	Left_Parahippocampal_G	scale	1	154	0.959
# hce	Left_Parahippocampal_G	llf	1	-8.74	-3.74e+03
# hce	Left_Parahippocampal_G	count	1	40.2	320
# hce	LeftMidHippocampus	Intercept_betas	0.000999	-8.07	-1.04
# hce	LeftMidHippocampus	correl_betas	0.518	0.698	0.061
# hce	LeftMidHippocampus	event_betas	0.000999	6.69	0.3
# hce	LeftMidHippocampus	ham_betas	0.019	2.9	0.0149
# hce	LeftMidHippocampus	Intercept_tvals	0.000999	-7.96	-3.38
# hce	LeftMidHippocampus	correl_tvals	0.548	0.682	0.265
# hce	LeftMidHippocampus	event_tvals	0.000999	6.7	6.88
# hce	LeftMidHippocampus	ham_tvals	0.013	3.26	1.96
# hce	LeftMidHippocampus	deviance	1	8.57	2.6e+03
# hce	LeftMidHippocampus	scale	1	170	0.972
# hce	LeftMidHippocampus	llf	1	-8.71	-3.76e+03
# hce	LeftMidHippocampus	count	1	24.3	64

# %%
permps
# Out:
# {'hce': {'LeftAntHippocampus.nii.gz': array([  9.99000999e-04,   2.24775225e-01,   9.99000999e-04,
#            1.93806194e-01,   9.99000999e-04,   1.70829171e-01,
#            9.99000999e-04,   2.02797203e-01,   9.98001998e-01,
#            1.00000000e+00,   9.98001998e-01,   1.00000000e+00]),
#   'LeftMidHippocampus.nii.gz': array([  9.99000999e-04,   5.18481518e-01,   9.99000999e-04,
#            1.89810190e-02,   9.99000999e-04,   5.48451548e-01,
#            9.99000999e-04,   1.29870130e-02,   1.00000000e+00,
#            1.00000000e+00,   1.00000000e+00,   1.00000000e+00]),
#   'LeftPostHippocampus.nii.gz': array([  9.99000999e-04,   6.76323676e-01,   9.99000999e-04,
#            6.79320679e-01,   9.99000999e-04,   7.07292707e-01,
#            9.99000999e-04,   4.98501499e-01,   9.96003996e-01,
#            9.99000999e-01,   9.88011988e-01,   1.00000000e+00]),
#   'Left_Parahippocampal_G.nii.gz': array([  9.99000999e-04,   5.58441558e-01,   9.99000999e-04,
#            4.89510490e-02,   9.99000999e-04,   4.19580420e-01,
#            9.99000999e-04,   4.59540460e-02,   1.00000000e+00,
#            1.00000000e+00,   1.00000000e+00,   1.00000000e+00]),
#   'Left_Posterior_V1.nii.gz': array([  9.99000999e-04,   7.76223776e-01,   9.99000999e-04,
#            4.28571429e-01,   9.99000999e-04,   5.99400599e-01,
#            9.99000999e-04,   4.08591409e-01,   1.49850150e-02,
#            9.97002997e-01,   1.59840160e-02,   1.00000000e+00]),
#   'RightAntHippocampus.nii.gz': array([  9.99000999e-04,   8.27172827e-01,   9.99000999e-04,
#            1.59840160e-01,   9.99000999e-04,   8.61138861e-01,
#            9.99000999e-04,   1.49850150e-01,   9.99000999e-04,
#            1.00000000e+00,   9.99000999e-04,   1.00000000e+00]),
#           0.67432567,  0.68931069,  0.89110889,  0.45254745,  0.27672328,
#           0.78121878,  0.001998  ,  0.05594406,  0.28171828,  0.91608392,
#           0.88711289,  0.76623377,  0.46253746,  0.22477522,  0.996004  ,
#           0.2027972 ,  1.        ]),
#   'RightPostHippocampus.nii.gz': array([  1.99800200e-03,   7.21278721e-01,   9.99000999e-04,
#            6.19380619e-02,   7.89210789e-02,   1.05894106e-01,
#            9.99000999e-02,   6.79320679e-02,   1.89810190e-02,
#            6.99300699e-03,   9.69030969e-01,   9.99000999e-04,
#            4.29570430e-02,   7.79220779e-02,   1.01898102e-01,
#            1.03896104e-01,   7.29270729e-02,   1.29870130e-02,
#            9.99000999e-04,   9.98001998e-01,   9.99000999e-04,
#            1.00000000e+00]),
#   'Right_Parahippocampal_G.nii.gz': array([  2.89710290e-02,   2.19780220e-01,   9.99000999e-04,
#            6.99300699e-02,   2.50749251e-01,   1.29870130e-01,
#            1.17882118e-01,   1.49850150e-01,   6.82317682e-01,
#            1.19880120e-02,   2.59740260e-01,   9.99000999e-04,
#            5.59440559e-02,   2.02797203e-01,   1.14885115e-01,
#            1.02897103e-01,   1.29870130e-01,   7.06293706e-01,
#            9.99000999e-04,   9.26073926e-01,   9.99000999e-04,
#            1.00000000e+00]),
#   'Right_Posterior_V1.nii.gz': array([  1.34865135e-01,   5.15484515e-01,   9.99000999e-04,
#            3.39660340e-02,   1.89810190e-02,   1.77822178e-01,
#            1.82817183e-01,   2.34765235e-01,   5.36463536e-01,
#            1.43856144e-01,   4.93506494e-01,   9.99000999e-04,
#            2.69730270e-02,   1.49850150e-02,   1.80819181e-01,
#            1.83816184e-01,   2.52747253e-01,   5.50449550e-01,
#            8.39160839e-02,   5.78421578e-01,   8.69130869e-02,
#            1.00000000e+00])}}

# %%
uncor_res = res_df.loc[res_df.Term.str.contains('betas') & ~res_df.Term.str.contains('Intercept') & ~res_df.Term.str.contains('event')& ~res_df.Term.str.contains('correl'),:]

# %%
uncor_res['bonferoni_p'] = uncor_res.p * 140
# Out:
# /spin1/users/nielsond/python/envs/py27mvpa/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
all_res = uncor_res.merge(true_res.loc[:,['model','ROI','term','all_term_all_roi_p']],
                left_on=['model','ROI','Term'],
                right_on = ['model','ROI','term'])

# %%
all_res.loc[all_res.bonferoni_p > 1, "bonferoni_p"] = 1

# %%
all_res.loc

# %%
all_res.query('p < 0.05')
# Out:
#       model                      ROI               Term         p         t  \
# 29   hvcest     RightPostHippocampus      viv_ave_betas  0.018981  3.000215
# 30   hvcest       Right_Posterior_V1          ham_betas  0.033966  2.641590
# 31   hvcest       Right_Posterior_V1  ham:viv_ave_betas  0.018981 -3.029674
# 38   hvcest       LeftAntHippocampus        space_betas  0.011988  3.170764
# 39   hvcest       LeftAntHippocampus   space:time_betas  0.028971 -2.635573
# 40   hvcest       LeftAntHippocampus         time_betas  0.023976  2.621255
# 54   hvcest       LeftMidHippocampus          ham_betas  0.001998  3.810661
# 74     hvce     RightPostHippocampus      viv_ave_betas  0.019980  2.911806
# 75     hvce       Right_Posterior_V1          ham_betas  0.028971  2.646504
# 76     hvce       Right_Posterior_V1  ham:viv_ave_betas  0.024975 -2.860631
# 87     hvce       LeftMidHippocampus          ham_betas  0.002997  3.659472
# 94    hcest  Right_Parahippocampal_G          ham_betas  0.035964  2.310488
# 102   hcest      RightMidHippocampus          ham_betas  0.001998  4.101808
# 106   hcest     RightPostHippocampus          ham_betas  0.040959  2.554056
# 115   hcest       LeftAntHippocampus        space_betas  0.014985  3.257338
# 116   hcest       LeftAntHippocampus   space:time_betas  0.023976 -2.776366
# 117   hcest       LeftAntHippocampus         time_betas  0.020979  2.731704
# 122   hcest   Left_Parahippocampal_G          ham_betas  0.049950  2.231149
# 126   hcest       LeftMidHippocampus          ham_betas  0.019980  2.966345
# 131     hce  Right_Parahippocampal_G          ham_betas  0.033966  2.382070
# 133     hce      RightMidHippocampus          ham_betas  0.001998  5.082741
# 134     hce     RightPostHippocampus          ham_betas  0.034965  2.589052
# 138     hce   Left_Parahippocampal_G          ham_betas  0.048951  2.228131
# 139     hce       LeftMidHippocampus          ham_betas  0.018981  2.903703
#
#          actp      beta  bonferoni_p               term  all_term_all_roi_p  \
# 29   0.151848  0.116402      1.00000      viv_ave_betas            0.550450
# 30   0.013986  0.022916      1.00000          ham_betas            0.740260
# 31   0.125874 -0.018423      1.00000  ham:viv_ave_betas            0.528472
# 38   0.139860  0.392455      1.00000        space_betas            0.460539
# 39   0.205794 -0.059070      1.00000   space:time_betas            0.743257
# 40   0.259740  0.172693      1.00000         time_betas            0.748252
# 54   0.002997  0.020510      0.27972          ham_betas            0.234765
# 74   0.161838  0.113128      1.00000      viv_ave_betas            0.594406
# 75   0.017982  0.022454      1.00000          ham_betas            0.737263
# 76   0.139860 -0.017685      1.00000  ham:viv_ave_betas            0.619381
# 87   0.002997  0.020401      0.41958          ham_betas            0.287712
# 94   0.017982  0.009946      1.00000          ham_betas            0.888112
# 102  0.003996  0.010982      0.27972          ham_betas            0.165834
# 106  0.014985  0.008465      1.00000          ham_betas            0.779221
# 115  0.115884  0.420354      1.00000        space_betas            0.426573
# 116  0.176823 -0.064230      1.00000   space:time_betas            0.671329
# 117  0.231768  0.187398      1.00000         time_betas            0.694306
# 122  0.033966  0.009238      1.00000          ham_betas            0.916084
# 126  0.000999  0.014920      1.00000          ham_betas            0.561439
# 131  0.012987  0.010179      1.00000          ham_betas            0.853147
# 133  0.001998  0.011991      0.27972          ham_betas            0.054945
# 134  0.016983  0.008505      1.00000          ham_betas            0.761239
# 138  0.034965  0.009272      1.00000          ham_betas            0.919081
# 139  0.000999  0.014920      1.00000          ham_betas            0.597403
#
#      bonbonferoni_p
# 29              1.0
# 30              1.0
# 31              1.0
# 38              1.0
# 39              1.0
# 40              1.0
# 54              NaN
# 74              1.0
# 75              1.0
# 76              1.0
# 87              NaN
# 94              1.0
# 102             NaN
# 106             1.0
# 115             1.0
# 116             1.0
# 117             1.0
# 122             1.0
# 126             1.0
# 131             1.0
# 133             NaN
# 134             1.0
# 138             1.0
# 139             1.0
